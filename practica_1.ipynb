# %% [markdown]
# 2019/2020 - MDS-1 - Extracción, Transformación y Carga - Etl

# %% [markdown]
# Raquel Fort Serra

# %% [markdown]
# # Práctica 1: Generación de ficheros de metadatos y lectura de formatos en python

# %% [markdown]
# Esta tarea consiste en, buscar información sobre estos formatos (json y yaml), e implementar sendas funciones ya sea en R o en python (recomendado), para poder leer este tipo de ficheros.

# %% [markdown]
# ##### Formato json

# %% [markdown]
# JSON es el acrónimo para JavaScript Object Notation, y aunque su nombre lo diga, no es necesariamente parte de JavaScript, de hecho es un estándar basado en texto plano para el intercambio de información, por lo que se usa en muchos sistemas que requieren mostrar o enviar información para ser interpretada por otros sistemas, la ventaja de JSON al ser un formato que es independiente de cualquier lenguaje de programación, es que los servicios que comparten información por éste método, no necesitan hablar el mismo idioma, es decir, el emisor puede ser Java y el receptor PHP, cada lenguaje tiene su propia librería para codificar y decodificar cadenas de JSON.
# JSON puede representar cuatro tipos primitivos(cadenas, números, booleanos, valores nulos) y dos tipos estructurados(objetos y arreglos).
# JSON puede ser leído por cualquier lenguaje de programación. Por lo tanto, puede ser usado para el intercambio de información entre distintas tecnologías.

# %%
import json
l = open("DATOS COMUNIDAD MADRID.json", encoding="utf8")
data = json.load(l)

# %%
data
# Out:
# {'data': [{'municipio_codigo': '001',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Acebeda (La)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '001',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Acebeda (La)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '001',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Acebeda (La)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '001',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Acebeda (La)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '001',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Acebeda (La)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '001',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Acebeda (La)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '001',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Acebeda (La)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '001',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Acebeda (La)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '001',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Acebeda (La)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '001',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Acebeda (La)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '001',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Acebeda (La)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '001',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Acebeda (La)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '001',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Acebeda (La)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '001',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Acebeda (La)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '001',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Acebeda (La)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '001',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Acebeda (La)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '001',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Acebeda (La)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '001',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Acebeda (La)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '002',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ajalvir',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '002',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ajalvir',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '002',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ajalvir',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '002',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 3,
#    'municipio_nombre': ' Ajalvir',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '002',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 8,
#    'municipio_nombre': ' Ajalvir',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '002',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 5,
#    'municipio_nombre': ' Ajalvir',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '002',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 4,
#    'municipio_nombre': ' Ajalvir',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '002',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ajalvir',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '002',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ajalvir',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '002',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ajalvir',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '002',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ajalvir',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '002',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Ajalvir',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '002',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Ajalvir',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '002',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 9,
#    'municipio_nombre': ' Ajalvir',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '002',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 5,
#    'municipio_nombre': ' Ajalvir',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '002',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ajalvir',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '002',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ajalvir',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '002',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ajalvir',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '003',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alameda del Valle',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '003',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alameda del Valle',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '003',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alameda del Valle',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '003',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alameda del Valle',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '003',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alameda del Valle',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '003',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alameda del Valle',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '003',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alameda del Valle',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '003',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alameda del Valle',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '003',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alameda del Valle',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '003',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alameda del Valle',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '003',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alameda del Valle',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '003',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alameda del Valle',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '003',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alameda del Valle',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '003',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alameda del Valle',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '003',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alameda del Valle',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '003',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alameda del Valle',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '003',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alameda del Valle',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '003',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alameda del Valle',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '004',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Álamo (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '004',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 2,
#    'municipio_nombre': ' Álamo (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '004',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 5,
#    'municipio_nombre': ' Álamo (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '004',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 12,
#    'municipio_nombre': ' Álamo (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '004',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 14,
#    'municipio_nombre': ' Álamo (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '004',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 8,
#    'municipio_nombre': ' Álamo (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '004',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 3,
#    'municipio_nombre': ' Álamo (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '004',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Álamo (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '004',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Álamo (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '004',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Álamo (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '004',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Álamo (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '004',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 7,
#    'municipio_nombre': ' Álamo (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '004',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 13,
#    'municipio_nombre': ' Álamo (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '004',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 14,
#    'municipio_nombre': ' Álamo (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '004',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 11,
#    'municipio_nombre': ' Álamo (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '004',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Álamo (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '004',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Álamo (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '004',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Álamo (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '005',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alcalá de Henares',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '005',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 19,
#    'municipio_nombre': ' Alcalá de Henares',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '005',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 54,
#    'municipio_nombre': ' Alcalá de Henares',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '005',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 137,
#    'municipio_nombre': ' Alcalá de Henares',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '005',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 285,
#    'municipio_nombre': ' Alcalá de Henares',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '005',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 253,
#    'municipio_nombre': ' Alcalá de Henares',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '005',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 57,
#    'municipio_nombre': ' Alcalá de Henares',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '005',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 3,
#    'municipio_nombre': ' Alcalá de Henares',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '005',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Alcalá de Henares',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '005',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alcalá de Henares',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '005',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 18,
#    'municipio_nombre': ' Alcalá de Henares',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '005',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 55,
#    'municipio_nombre': ' Alcalá de Henares',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '005',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 125,
#    'municipio_nombre': ' Alcalá de Henares',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '005',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 285,
#    'municipio_nombre': ' Alcalá de Henares',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '005',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 246,
#    'municipio_nombre': ' Alcalá de Henares',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '005',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 64,
#    'municipio_nombre': ' Alcalá de Henares',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '005',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 7,
#    'municipio_nombre': ' Alcalá de Henares',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '005',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alcalá de Henares',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '006',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alcobendas',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '006',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 6,
#    'municipio_nombre': ' Alcobendas',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '006',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 28,
#    'municipio_nombre': ' Alcobendas',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '006',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 68,
#    'municipio_nombre': ' Alcobendas',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '006',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 163,
#    'municipio_nombre': ' Alcobendas',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '006',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 177,
#    'municipio_nombre': ' Alcobendas',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '006',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 51,
#    'municipio_nombre': ' Alcobendas',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '006',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 7,
#    'municipio_nombre': ' Alcobendas',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '006',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alcobendas',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '006',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alcobendas',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '006',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 10,
#    'municipio_nombre': ' Alcobendas',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '006',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 28,
#    'municipio_nombre': ' Alcobendas',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '006',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 70,
#    'municipio_nombre': ' Alcobendas',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '006',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 159,
#    'municipio_nombre': ' Alcobendas',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '006',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 163,
#    'municipio_nombre': ' Alcobendas',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '006',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 51,
#    'municipio_nombre': ' Alcobendas',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '006',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 4,
#    'municipio_nombre': ' Alcobendas',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '006',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alcobendas',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '007',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alcorcón',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '007',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 8,
#    'municipio_nombre': ' Alcorcón',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '007',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 36,
#    'municipio_nombre': ' Alcorcón',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '007',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 104,
#    'municipio_nombre': ' Alcorcón',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '007',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 212,
#    'municipio_nombre': ' Alcorcón',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '007',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 268,
#    'municipio_nombre': ' Alcorcón',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '007',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 88,
#    'municipio_nombre': ' Alcorcón',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '007',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 5,
#    'municipio_nombre': ' Alcorcón',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '007',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Alcorcón',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '007',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alcorcón',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '007',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 6,
#    'municipio_nombre': ' Alcorcón',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '007',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 33,
#    'municipio_nombre': ' Alcorcón',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '007',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 96,
#    'municipio_nombre': ' Alcorcón',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '007',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 229,
#    'municipio_nombre': ' Alcorcón',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '007',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 269,
#    'municipio_nombre': ' Alcorcón',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '007',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 88,
#    'municipio_nombre': ' Alcorcón',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '007',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 6,
#    'municipio_nombre': ' Alcorcón',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '007',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alcorcón',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '008',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Aldea del Fresno',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '008',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Aldea del Fresno',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '008',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Aldea del Fresno',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '008',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 5,
#    'municipio_nombre': ' Aldea del Fresno',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '008',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Aldea del Fresno',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '008',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 2,
#    'municipio_nombre': ' Aldea del Fresno',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '008',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Aldea del Fresno',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '008',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Aldea del Fresno',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '008',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Aldea del Fresno',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '008',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Aldea del Fresno',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '008',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Aldea del Fresno',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '008',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Aldea del Fresno',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '008',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 3,
#    'municipio_nombre': ' Aldea del Fresno',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '008',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 9,
#    'municipio_nombre': ' Aldea del Fresno',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '008',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Aldea del Fresno',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '008',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Aldea del Fresno',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '008',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Aldea del Fresno',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '008',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Aldea del Fresno',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '009',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Algete',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '009',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Algete',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '009',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 2,
#    'municipio_nombre': ' Algete',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '009',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 16,
#    'municipio_nombre': ' Algete',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '009',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 28,
#    'municipio_nombre': ' Algete',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '009',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 20,
#    'municipio_nombre': ' Algete',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '009',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 6,
#    'municipio_nombre': ' Algete',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '009',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Algete',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '009',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Algete',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '009',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Algete',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '009',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Algete',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '009',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 3,
#    'municipio_nombre': ' Algete',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '009',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 17,
#    'municipio_nombre': ' Algete',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '009',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 31,
#    'municipio_nombre': ' Algete',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '009',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 34,
#    'municipio_nombre': ' Algete',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '009',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 3,
#    'municipio_nombre': ' Algete',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '009',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Algete',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '009',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Algete',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '010',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alpedrete',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '010',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alpedrete',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '010',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 2,
#    'municipio_nombre': ' Alpedrete',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '010',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 11,
#    'municipio_nombre': ' Alpedrete',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '010',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 20,
#    'municipio_nombre': ' Alpedrete',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '010',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 22,
#    'municipio_nombre': ' Alpedrete',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '010',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 6,
#    'municipio_nombre': ' Alpedrete',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '010',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alpedrete',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '010',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alpedrete',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '010',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alpedrete',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '010',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alpedrete',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '010',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alpedrete',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '010',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 5,
#    'municipio_nombre': ' Alpedrete',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '010',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 20,
#    'municipio_nombre': ' Alpedrete',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '010',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 21,
#    'municipio_nombre': ' Alpedrete',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '010',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 4,
#    'municipio_nombre': ' Alpedrete',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '010',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Alpedrete',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '010',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Alpedrete',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '011',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ambite',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '011',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ambite',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '011',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ambite',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '011',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Ambite',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '011',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ambite',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '011',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ambite',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '011',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ambite',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '011',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ambite',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '011',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ambite',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '011',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ambite',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '011',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ambite',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '011',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ambite',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '011',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Ambite',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '011',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Ambite',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '011',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Ambite',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '011',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ambite',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '011',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ambite',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '011',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Ambite',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '012',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Anchuelo',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '012',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Anchuelo',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '012',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Anchuelo',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '012',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 2,
#    'municipio_nombre': ' Anchuelo',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '012',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 2,
#    'municipio_nombre': ' Anchuelo',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '012',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 9,
#    'municipio_nombre': ' Anchuelo',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '012',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Anchuelo',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '012',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Anchuelo',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '012',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Anchuelo',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '012',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Anchuelo',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '012',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Anchuelo',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '012',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Anchuelo',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '012',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 3,
#    'municipio_nombre': ' Anchuelo',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '012',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 3,
#    'municipio_nombre': ' Anchuelo',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '012',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Anchuelo',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '012',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Anchuelo',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '012',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Anchuelo',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '012',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Anchuelo',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '013',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Aranjuez',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '013',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 9,
#    'municipio_nombre': ' Aranjuez',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '013',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 25,
#    'municipio_nombre': ' Aranjuez',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '013',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 54,
#    'municipio_nombre': ' Aranjuez',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '013',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 106,
#    'municipio_nombre': ' Aranjuez',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '013',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 104,
#    'municipio_nombre': ' Aranjuez',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '013',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 14,
#    'municipio_nombre': ' Aranjuez',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '013',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 4,
#    'municipio_nombre': ' Aranjuez',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '013',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Aranjuez',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '013',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Aranjuez',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '013',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 8,
#    'municipio_nombre': ' Aranjuez',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '013',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 20,
#    'municipio_nombre': ' Aranjuez',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '013',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 53,
#    'municipio_nombre': ' Aranjuez',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '013',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 88,
#    'municipio_nombre': ' Aranjuez',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '013',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 71,
#    'municipio_nombre': ' Aranjuez',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '013',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 21,
#    'municipio_nombre': ' Aranjuez',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '013',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 2,
#    'municipio_nombre': ' Aranjuez',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '013',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Aranjuez',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '014',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Arganda del Rey',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '014',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 2,
#    'municipio_nombre': ' Arganda del Rey',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '014',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 12,
#    'municipio_nombre': ' Arganda del Rey',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '014',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 58,
#    'municipio_nombre': ' Arganda del Rey',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '014',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 118,
#    'municipio_nombre': ' Arganda del Rey',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '014',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 95,
#    'municipio_nombre': ' Arganda del Rey',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '014',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 17,
#    'municipio_nombre': ' Arganda del Rey',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '014',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Arganda del Rey',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '014',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Arganda del Rey',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '014',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Arganda del Rey',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '014',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Arganda del Rey',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '014',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 18,
#    'municipio_nombre': ' Arganda del Rey',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '014',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 52,
#    'municipio_nombre': ' Arganda del Rey',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '014',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 90,
#    'municipio_nombre': ' Arganda del Rey',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '014',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 75,
#    'municipio_nombre': ' Arganda del Rey',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '014',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 25,
#    'municipio_nombre': ' Arganda del Rey',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '014',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Arganda del Rey',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '014',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Arganda del Rey',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '015',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Arroyomolinos',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '015',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 2,
#    'municipio_nombre': ' Arroyomolinos',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '015',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 5,
#    'municipio_nombre': ' Arroyomolinos',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '015',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 28,
#    'municipio_nombre': ' Arroyomolinos',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '015',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 98,
#    'municipio_nombre': ' Arroyomolinos',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '015',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 101,
#    'municipio_nombre': ' Arroyomolinos',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '015',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 24,
#    'municipio_nombre': ' Arroyomolinos',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '015',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 3,
#    'municipio_nombre': ' Arroyomolinos',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '015',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Arroyomolinos',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '015',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Arroyomolinos',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '015',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Arroyomolinos',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '015',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 2,
#    'municipio_nombre': ' Arroyomolinos',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '015',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 21,
#    'municipio_nombre': ' Arroyomolinos',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '015',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 81,
#    'municipio_nombre': ' Arroyomolinos',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '015',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 85,
#    'municipio_nombre': ' Arroyomolinos',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '015',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 14,
#    'municipio_nombre': ' Arroyomolinos',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '015',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 4,
#    'municipio_nombre': ' Arroyomolinos',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '015',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Arroyomolinos',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '016',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Atazar (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '016',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Atazar (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '016',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Atazar (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '016',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Atazar (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '016',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Atazar (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '016',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Atazar (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '016',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Atazar (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '016',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Atazar (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '016',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Atazar (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '016',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Atazar (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '016',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Atazar (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '016',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Atazar (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '016',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Atazar (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '016',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Atazar (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '016',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Atazar (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '016',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Atazar (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '016',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Atazar (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '016',
# ...
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 25,
#    'municipio_nombre': ' Coslada',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '049',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 2,
#    'municipio_nombre': ' Coslada',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '049',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Coslada',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '049',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Coslada',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '049',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 3,
#    'municipio_nombre': ' Coslada',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '049',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 17,
#    'municipio_nombre': ' Coslada',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '049',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 62,
#    'municipio_nombre': ' Coslada',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '049',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 109,
#    'municipio_nombre': ' Coslada',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '049',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 95,
#    'municipio_nombre': ' Coslada',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '049',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 23,
#    'municipio_nombre': ' Coslada',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '049',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 3,
#    'municipio_nombre': ' Coslada',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '049',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Coslada',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '050',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Cubas de la Sagra',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '050',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Cubas de la Sagra',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '050',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 2,
#    'municipio_nombre': ' Cubas de la Sagra',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '050',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 3,
#    'municipio_nombre': ' Cubas de la Sagra',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '050',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 10,
#    'municipio_nombre': ' Cubas de la Sagra',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '050',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 9,
#    'municipio_nombre': ' Cubas de la Sagra',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '050',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 4,
#    'municipio_nombre': ' Cubas de la Sagra',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '050',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Cubas de la Sagra',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '050',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Cubas de la Sagra',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '050',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Cubas de la Sagra',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '050',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Cubas de la Sagra',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '050',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Cubas de la Sagra',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '050',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 2,
#    'municipio_nombre': ' Cubas de la Sagra',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '050',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 11,
#    'municipio_nombre': ' Cubas de la Sagra',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '050',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 15,
#    'municipio_nombre': ' Cubas de la Sagra',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '050',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 6,
#    'municipio_nombre': ' Cubas de la Sagra',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '050',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Cubas de la Sagra',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '050',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Cubas de la Sagra',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '053',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Daganzo de Arriba',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '053',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Daganzo de Arriba',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '053',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 4,
#    'municipio_nombre': ' Daganzo de Arriba',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '053',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 4,
#    'municipio_nombre': ' Daganzo de Arriba',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '053',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 14,
#    'municipio_nombre': ' Daganzo de Arriba',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '053',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 14,
#    'municipio_nombre': ' Daganzo de Arriba',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '053',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 5,
#    'municipio_nombre': ' Daganzo de Arriba',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '053',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Daganzo de Arriba',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '053',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Daganzo de Arriba',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '053',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Daganzo de Arriba',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '053',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Daganzo de Arriba',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '053',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Daganzo de Arriba',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '053',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 2,
#    'municipio_nombre': ' Daganzo de Arriba',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '053',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 22,
#    'municipio_nombre': ' Daganzo de Arriba',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '053',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 12,
#    'municipio_nombre': ' Daganzo de Arriba',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '053',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 3,
#    'municipio_nombre': ' Daganzo de Arriba',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '053',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Daganzo de Arriba',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '053',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Daganzo de Arriba',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '054',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Escorial (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '054',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Escorial (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '054',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Escorial (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '054',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 14,
#    'municipio_nombre': ' Escorial (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '054',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 25,
#    'municipio_nombre': ' Escorial (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '054',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 20,
#    'municipio_nombre': ' Escorial (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '054',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 6,
#    'municipio_nombre': ' Escorial (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '054',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Escorial (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '054',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Escorial (El)',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '054',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Escorial (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '054',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Escorial (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '054',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 2,
#    'municipio_nombre': ' Escorial (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '054',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 13,
#    'municipio_nombre': ' Escorial (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '054',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 23,
#    'municipio_nombre': ' Escorial (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '054',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 19,
#    'municipio_nombre': ' Escorial (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '054',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 7,
#    'municipio_nombre': ' Escorial (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '054',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Escorial (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '054',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Escorial (El)',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '055',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Estremera',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '055',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Estremera',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '055',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Estremera',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '055',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Estremera',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '055',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Estremera',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '055',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Estremera',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '055',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Estremera',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '055',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Estremera',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '055',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Estremera',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '055',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Estremera',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '055',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Estremera',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '055',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Estremera',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '055',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Estremera',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '055',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Estremera',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '055',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 3,
#    'municipio_nombre': ' Estremera',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '055',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Estremera',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '055',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Estremera',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '055',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Estremera',
#    'sexo': 'Mujer'},
#   {'municipio_codigo': '056',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Fresnedillas de la Oliva',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '056',
#    'rango_edad_de_la_madre': 'De 15 a 19 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Fresnedillas de la Oliva',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '056',
#    'rango_edad_de_la_madre': 'De 20 a 24 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Fresnedillas de la Oliva',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '056',
#    'rango_edad_de_la_madre': 'De 25 a 29 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Fresnedillas de la Oliva',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '056',
#    'rango_edad_de_la_madre': 'De 30 a 34 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Fresnedillas de la Oliva',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '056',
#    'rango_edad_de_la_madre': 'De 35 a 39 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Fresnedillas de la Oliva',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '056',
#    'rango_edad_de_la_madre': 'De 40 a 44 años',
#    'numero_nacimientos': 1,
#    'municipio_nombre': ' Fresnedillas de la Oliva',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '056',
#    'rango_edad_de_la_madre': 'De 45 a 49 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Fresnedillas de la Oliva',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '056',
#    'rango_edad_de_la_madre': 'De 50 años y más',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Fresnedillas de la Oliva',
#    'sexo': 'Hombre'},
#   {'municipio_codigo': '056',
#    'rango_edad_de_la_madre': 'Menores de 15 años',
#    'numero_nacimientos': 0,
#    'municipio_nombre': ' Fresnedillas de la Oliva',
#    'sexo': 'Mujer'},
#   ...]}

# %% [markdown]
# ##### Formato yaml

# %% [markdown]
# YAML es un formato para guardar objetos de datos con estructura de árbol. Sus siglas significan YAML Ain’t Markup Language (YAML no es otro lenguaje de marcado).
# Este lenguaje es muy legible y se utiliza normalmente para archivos de configuración, traducciones y representar información.
# Un dato importante es que no se usa para Web Services o APIs Rest, ya que como se menciona antes, normalmente es utilizado como archivo de configuración.

# %%
import yaml
def readfile 
with open(r'1082591.yaml') as file:
    doc = yaml.load(file, Loader = yaml.FullLoader)
    data2 = yaml.dump(doc, sort_keys = True)

    print(data2)
# Out:
# info:
#   city: Hyderabad
#   competition: IPL
#   dates:
#   - 2017-04-05
#   gender: male
#   match_type: T20
#   outcome:
#     by:
#       runs: 35
#     winner: Sunrisers Hyderabad
#   overs: 20
#   player_of_match:
#   - Yuvraj Singh
#   teams:
#   - Sunrisers Hyderabad
#   - Royal Challengers Bangalore
#   toss:
#     decision: field
#     winner: Royal Challengers Bangalore
#   umpires:
#   - AY Dandekar
#   - NJ Llong
#   venue: Rajiv Gandhi International Stadium, Uppal
# innings:
# - 1st innings:
#     deliveries:
#     - 0.1:
#         batsman: DA Warner
#         bowler: TS Mills
#         non_striker: S Dhawan
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 0.2:
#         batsman: DA Warner
#         bowler: TS Mills
#         non_striker: S Dhawan
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 0.3:
#         batsman: DA Warner
#         bowler: TS Mills
#         non_striker: S Dhawan
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 0.4:
#         batsman: DA Warner
#         bowler: TS Mills
#         non_striker: S Dhawan
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 0.5:
#         batsman: DA Warner
#         bowler: TS Mills
#         extras:
#           wides: 2
#         non_striker: S Dhawan
#         runs:
#           batsman: 0
#           extras: 2
#           total: 2
#     - 0.6:
#         batsman: S Dhawan
#         bowler: TS Mills
#         non_striker: DA Warner
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 0.7:
#         batsman: S Dhawan
#         bowler: TS Mills
#         extras:
#           legbyes: 1
#         non_striker: DA Warner
#         runs:
#           batsman: 0
#           extras: 1
#           total: 1
#     - 1.1:
#         batsman: S Dhawan
#         bowler: A Choudhary
#         non_striker: DA Warner
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 1.2:
#         batsman: DA Warner
#         bowler: A Choudhary
#         non_striker: S Dhawan
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 1.3:
#         batsman: DA Warner
#         bowler: A Choudhary
#         extras:
#           noballs: 1
#         non_striker: S Dhawan
#         runs:
#           batsman: 0
#           extras: 1
#           total: 1
#     - 1.4:
#         batsman: DA Warner
#         bowler: A Choudhary
#         non_striker: S Dhawan
#         runs:
#           batsman: 6
#           extras: 0
#           total: 6
#     - 1.5:
#         batsman: DA Warner
#         bowler: A Choudhary
#         non_striker: S Dhawan
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           fielders:
#           - Mandeep Singh
#           kind: caught
#           player_out: DA Warner
#     - 1.6:
#         batsman: MC Henriques
#         bowler: A Choudhary
#         non_striker: S Dhawan
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 1.7:
#         batsman: MC Henriques
#         bowler: A Choudhary
#         non_striker: S Dhawan
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 2.1:
#         batsman: S Dhawan
#         bowler: TS Mills
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 2.2:
#         batsman: MC Henriques
#         bowler: TS Mills
#         non_striker: S Dhawan
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 2.3:
#         batsman: MC Henriques
#         bowler: TS Mills
#         non_striker: S Dhawan
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 2.4:
#         batsman: MC Henriques
#         bowler: TS Mills
#         non_striker: S Dhawan
#         runs:
#           batsman: 3
#           extras: 0
#           total: 3
#     - 2.5:
#         batsman: S Dhawan
#         bowler: TS Mills
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 2.6:
#         batsman: MC Henriques
#         bowler: TS Mills
#         non_striker: S Dhawan
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 3.1:
#         batsman: MC Henriques
#         bowler: YS Chahal
#         non_striker: S Dhawan
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 3.2:
#         batsman: MC Henriques
#         bowler: YS Chahal
#         non_striker: S Dhawan
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 3.3:
#         batsman: S Dhawan
#         bowler: YS Chahal
#         non_striker: MC Henriques
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 3.4:
#         batsman: S Dhawan
#         bowler: YS Chahal
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 3.5:
#         batsman: MC Henriques
#         bowler: YS Chahal
#         non_striker: S Dhawan
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 3.6:
#         batsman: S Dhawan
#         bowler: YS Chahal
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 4.1:
#         batsman: S Dhawan
#         bowler: S Aravind
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 4.2:
#         batsman: MC Henriques
#         bowler: S Aravind
#         non_striker: S Dhawan
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 4.3:
#         batsman: S Dhawan
#         bowler: S Aravind
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 4.4:
#         batsman: MC Henriques
#         bowler: S Aravind
#         non_striker: S Dhawan
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 4.5:
#         batsman: MC Henriques
#         bowler: S Aravind
#         non_striker: S Dhawan
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 4.6:
#         batsman: MC Henriques
#         bowler: S Aravind
#         non_striker: S Dhawan
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 5.1:
#         batsman: S Dhawan
#         bowler: SR Watson
#         non_striker: MC Henriques
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 5.2:
#         batsman: S Dhawan
#         bowler: SR Watson
#         non_striker: MC Henriques
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 5.3:
#         batsman: S Dhawan
#         bowler: SR Watson
#         non_striker: MC Henriques
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 5.4:
#         batsman: S Dhawan
#         bowler: SR Watson
#         non_striker: MC Henriques
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 5.5:
#         batsman: S Dhawan
#         bowler: SR Watson
#         non_striker: MC Henriques
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 5.6:
#         batsman: S Dhawan
#         bowler: SR Watson
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 6.1:
#         batsman: S Dhawan
#         bowler: YS Chahal
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 6.2:
#         batsman: MC Henriques
#         bowler: YS Chahal
#         non_striker: S Dhawan
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 6.3:
#         batsman: MC Henriques
#         bowler: YS Chahal
#         non_striker: S Dhawan
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 6.4:
#         batsman: S Dhawan
#         bowler: YS Chahal
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 6.5:
#         batsman: MC Henriques
#         bowler: YS Chahal
#         non_striker: S Dhawan
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 6.6:
#         batsman: S Dhawan
#         bowler: YS Chahal
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 7.1:
#         batsman: S Dhawan
#         bowler: TM Head
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 7.2:
#         batsman: MC Henriques
#         bowler: TM Head
#         non_striker: S Dhawan
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 7.3:
#         batsman: S Dhawan
#         bowler: TM Head
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 7.4:
#         batsman: MC Henriques
#         bowler: TM Head
#         non_striker: S Dhawan
#         runs:
#           batsman: 6
#           extras: 0
#           total: 6
#     - 7.5:
#         batsman: MC Henriques
#         bowler: TM Head
#         non_striker: S Dhawan
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 7.6:
#         batsman: S Dhawan
#         bowler: TM Head
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 8.1:
#         batsman: S Dhawan
#         bowler: YS Chahal
#         non_striker: MC Henriques
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 8.2:
#         batsman: S Dhawan
#         bowler: YS Chahal
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 8.3:
#         batsman: MC Henriques
#         bowler: YS Chahal
#         non_striker: S Dhawan
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 8.4:
#         batsman: S Dhawan
#         bowler: YS Chahal
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 8.5:
#         batsman: MC Henriques
#         bowler: YS Chahal
#         non_striker: S Dhawan
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 8.6:
#         batsman: MC Henriques
#         bowler: YS Chahal
#         non_striker: S Dhawan
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 9.1:
#         batsman: S Dhawan
#         bowler: A Choudhary
#         non_striker: MC Henriques
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 9.2:
#         batsman: S Dhawan
#         bowler: A Choudhary
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 9.3:
#         batsman: MC Henriques
#         bowler: A Choudhary
#         non_striker: S Dhawan
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 9.4:
#         batsman: S Dhawan
#         bowler: A Choudhary
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 9.5:
#         batsman: MC Henriques
#         bowler: A Choudhary
#         non_striker: S Dhawan
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 9.6:
#         batsman: S Dhawan
#         bowler: A Choudhary
#         non_striker: MC Henriques
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 10.1:
#         batsman: MC Henriques
#         bowler: STR Binny
#         non_striker: S Dhawan
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 10.2:
#         batsman: S Dhawan
#         bowler: STR Binny
#         non_striker: MC Henriques
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 10.3:
#         batsman: S Dhawan
#         bowler: STR Binny
#         non_striker: MC Henriques
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           fielders:
#           - Sachin Baby
#           kind: caught
#           player_out: S Dhawan
#     - 10.4:
#         batsman: MC Henriques
#         bowler: STR Binny
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 10.5:
#         batsman: Yuvraj Singh
#         bowler: STR Binny
#         non_striker: MC Henriques
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 10.6:
#         batsman: Yuvraj Singh
#         bowler: STR Binny
#         non_striker: MC Henriques
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 11.1:
#         batsman: MC Henriques
#         bowler: S Aravind
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 11.2:
#         batsman: Yuvraj Singh
#         bowler: S Aravind
#         non_striker: MC Henriques
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 11.3:
#         batsman: Yuvraj Singh
#         bowler: S Aravind
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 11.4:
#         batsman: MC Henriques
#         bowler: S Aravind
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 11.5:
#         batsman: Yuvraj Singh
#         bowler: S Aravind
#         non_striker: MC Henriques
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 11.6:
#         batsman: Yuvraj Singh
#         bowler: S Aravind
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 12.1:
#         batsman: Yuvraj Singh
#         bowler: A Choudhary
#         non_striker: MC Henriques
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 12.2:
#         batsman: Yuvraj Singh
#         bowler: A Choudhary
#         non_striker: MC Henriques
#         runs:
#           batsman: 6
#           extras: 0
#           total: 6
#     - 12.3:
#         batsman: Yuvraj Singh
#         bowler: A Choudhary
#         non_striker: MC Henriques
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 12.4:
#         batsman: Yuvraj Singh
#         bowler: A Choudhary
#         non_striker: MC Henriques
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 12.5:
#         batsman: Yuvraj Singh
#         bowler: A Choudhary
#         extras:
#           wides: 1
#         non_striker: MC Henriques
#         runs:
#           batsman: 0
#           extras: 1
#           total: 1
#     - 12.6:
#         batsman: Yuvraj Singh
#         bowler: A Choudhary
#         non_striker: MC Henriques
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 12.7:
#         batsman: Yuvraj Singh
#         bowler: A Choudhary
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 13.1:
#         batsman: Yuvraj Singh
#         bowler: SR Watson
#         non_striker: MC Henriques
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 13.2:
#         batsman: Yuvraj Singh
#         bowler: SR Watson
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 13.3:
#         batsman: MC Henriques
#         bowler: SR Watson
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 13.4:
#         batsman: Yuvraj Singh
#         bowler: SR Watson
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 13.5:
#         batsman: MC Henriques
#         bowler: SR Watson
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 13.6:
#         batsman: MC Henriques
#         bowler: SR Watson
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 14.1:
#         batsman: MC Henriques
#         bowler: S Aravind
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 14.2:
#         batsman: MC Henriques
#         bowler: S Aravind
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 14.3:
#         batsman: Yuvraj Singh
#         bowler: S Aravind
#         non_striker: MC Henriques
#         runs:
#           batsman: 6
#           extras: 0
#           total: 6
#     - 14.4:
#         batsman: Yuvraj Singh
#         bowler: S Aravind
#         non_striker: MC Henriques
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 14.5:
#         batsman: MC Henriques
#         bowler: S Aravind
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 6
#           extras: 0
#           total: 6
#     - 14.6:
#         batsman: MC Henriques
#         bowler: S Aravind
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 15.1:
#         batsman: MC Henriques
#         bowler: YS Chahal
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 15.2:
#         batsman: MC Henriques
#         bowler: YS Chahal
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           fielders:
#           - Sachin Baby
#           kind: caught
#           player_out: MC Henriques
#     - 15.3:
#         batsman: Yuvraj Singh
#         bowler: YS Chahal
#         non_striker: DJ Hooda
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 15.4:
#         batsman: DJ Hooda
#         bowler: YS Chahal
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 15.5:
#         batsman: Yuvraj Singh
#         bowler: YS Chahal
#         non_striker: DJ Hooda
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 15.6:
#         batsman: DJ Hooda
#         bowler: YS Chahal
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 16.1:
#         batsman: DJ Hooda
#         bowler: TS Mills
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 16.2:
#         batsman: Yuvraj Singh
#         bowler: TS Mills
#         non_striker: DJ Hooda
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 16.3:
#         batsman: Yuvraj Singh
#         bowler: TS Mills
#         non_striker: DJ Hooda
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 16.4:
#         batsman: Yuvraj Singh
#         bowler: TS Mills
#         non_striker: DJ Hooda
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 16.5:
#         batsman: DJ Hooda
#         bowler: TS Mills
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 16.6:
#         batsman: DJ Hooda
#         bowler: TS Mills
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 17.1:
#         batsman: DJ Hooda
#         bowler: A Choudhary
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 6
#           extras: 0
#           total: 6
#     - 17.2:
#         batsman: DJ Hooda
#         bowler: A Choudhary
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 17.3:
#         batsman: Yuvraj Singh
#         bowler: A Choudhary
#         extras:
#           wides: 1
#         non_striker: DJ Hooda
#         runs:
#           batsman: 0
#           extras: 1
#           total: 1
#     - 17.4:
#         batsman: Yuvraj Singh
#         bowler: A Choudhary
#         extras:
#           wides: 1
#         non_striker: DJ Hooda
#         runs:
#           batsman: 0
#           extras: 1
#           total: 1
#     - 17.5:
#         batsman: Yuvraj Singh
#         bowler: A Choudhary
#         non_striker: DJ Hooda
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 17.6:
#         batsman: Yuvraj Singh
#         bowler: A Choudhary
#         non_striker: DJ Hooda
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 17.7:
#         batsman: DJ Hooda
#         bowler: A Choudhary
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 17.8:
#         batsman: DJ Hooda
#         bowler: A Choudhary
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 18.1:
#         batsman: DJ Hooda
#         bowler: TS Mills
#         non_striker: Yuvraj Singh
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 18.2:
#         batsman: Yuvraj Singh
#         bowler: TS Mills
#         non_striker: DJ Hooda
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 18.3:
#         batsman: Yuvraj Singh
#         bowler: TS Mills
#         non_striker: DJ Hooda
#         runs:
#           batsman: 6
#           extras: 0
#           total: 6
#     - 18.4:
#         batsman: Yuvraj Singh
#         bowler: TS Mills
#         non_striker: DJ Hooda
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           kind: bowled
#           player_out: Yuvraj Singh
#     - 18.5:
#         batsman: BCJ Cutting
#         bowler: TS Mills
#         non_striker: DJ Hooda
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 18.6:
#         batsman: DJ Hooda
#         bowler: TS Mills
#         non_striker: BCJ Cutting
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 19.1:
#         batsman: BCJ Cutting
#         bowler: SR Watson
#         non_striker: DJ Hooda
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 19.2:
#         batsman: DJ Hooda
#         bowler: SR Watson
#         non_striker: BCJ Cutting
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 19.3:
#         batsman: BCJ Cutting
#         bowler: SR Watson
#         non_striker: DJ Hooda
#         runs:
#           batsman: 6
#           extras: 0
#           total: 6
#     - 19.4:
#         batsman: BCJ Cutting
#         bowler: SR Watson
#         non_striker: DJ Hooda
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 19.5:
#         batsman: BCJ Cutting
#         bowler: SR Watson
#         non_striker: DJ Hooda
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 19.6:
#         batsman: BCJ Cutting
#         bowler: SR Watson
#         non_striker: DJ Hooda
#         runs:
#           batsman: 6
#           extras: 0
#           total: 6
#     team: Sunrisers Hyderabad
# - 2nd innings:
#     deliveries:
#     - 0.1:
#         batsman: CH Gayle
#         bowler: A Nehra
#         non_striker: Mandeep Singh
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 0.2:
#         batsman: Mandeep Singh
#         bowler: A Nehra
#         non_striker: CH Gayle
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 0.3:
#         batsman: Mandeep Singh
#         bowler: A Nehra
#         non_striker: CH Gayle
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 0.4:
#         batsman: Mandeep Singh
#         bowler: A Nehra
#         non_striker: CH Gayle
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 0.5:
#         batsman: Mandeep Singh
#         bowler: A Nehra
#         non_striker: CH Gayle
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 0.6:
#         batsman: Mandeep Singh
#         bowler: A Nehra
#         non_striker: CH Gayle
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 1.1:
#         batsman: CH Gayle
#         bowler: B Kumar
#         non_striker: Mandeep Singh
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 1.2:
#         batsman: CH Gayle
#         bowler: B Kumar
#         non_striker: Mandeep Singh
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 1.3:
#         batsman: CH Gayle
#         bowler: B Kumar
#         non_striker: Mandeep Singh
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 1.4:
#         batsman: Mandeep Singh
#         bowler: B Kumar
#         non_striker: CH Gayle
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 1.5:
#         batsman: Mandeep Singh
#         bowler: B Kumar
#         non_striker: CH Gayle
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 1.6:
#         batsman: Mandeep Singh
#         bowler: B Kumar
#         non_striker: CH Gayle
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 2.1:
#         batsman: CH Gayle
#         bowler: A Nehra
#         non_striker: Mandeep Singh
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 2.2:
#         batsman: CH Gayle
#         bowler: A Nehra
#         non_striker: Mandeep Singh
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 2.3:
#         batsman: CH Gayle
#         bowler: A Nehra
#         non_striker: Mandeep Singh
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 2.4:
#         batsman: Mandeep Singh
#         bowler: A Nehra
#         non_striker: CH Gayle
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 2.5:
#         batsman: Mandeep Singh
#         bowler: A Nehra
#         non_striker: CH Gayle
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 2.6:
#         batsman: CH Gayle
#         bowler: A Nehra
#         non_striker: Mandeep Singh
#         runs:
#           batsman: 6
#           extras: 0
#           total: 6
#     - 3.1:
#         batsman: Mandeep Singh
#         bowler: B Kumar
#         non_striker: CH Gayle
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 3.2:
#         batsman: CH Gayle
#         bowler: B Kumar
#         non_striker: Mandeep Singh
#         runs:
#           batsman: 6
#           extras: 0
#           total: 6
#     - 3.3:
#         batsman: CH Gayle
#         bowler: B Kumar
#         non_striker: Mandeep Singh
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 3.4:
#         batsman: CH Gayle
#         bowler: B Kumar
#         extras:
#           wides: 1
#         non_striker: Mandeep Singh
#         runs:
#           batsman: 0
#           extras: 1
#           total: 1
#     - 3.5:
#         batsman: CH Gayle
#         bowler: B Kumar
#         non_striker: Mandeep Singh
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 3.6:
#         batsman: CH Gayle
#         bowler: B Kumar
#         non_striker: Mandeep Singh
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 3.7:
#         batsman: Mandeep Singh
#         bowler: B Kumar
#         non_striker: CH Gayle
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 4.1:
#         batsman: CH Gayle
#         bowler: BCJ Cutting
#         non_striker: Mandeep Singh
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 4.2:
#         batsman: CH Gayle
#         bowler: BCJ Cutting
#         non_striker: Mandeep Singh
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 4.3:
#         batsman: CH Gayle
#         bowler: BCJ Cutting
#         non_striker: Mandeep Singh
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 4.4:
#         batsman: CH Gayle
#         bowler: BCJ Cutting
#         extras:
#           wides: 1
#         non_striker: Mandeep Singh
#         runs:
#           batsman: 0
#           extras: 1
#           total: 1
#     - 4.5:
#         batsman: CH Gayle
#         bowler: BCJ Cutting
#         non_striker: Mandeep Singh
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 4.6:
#         batsman: CH Gayle
#         bowler: BCJ Cutting
#         non_striker: Mandeep Singh
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 4.7:
#         batsman: CH Gayle
#         bowler: BCJ Cutting
#         non_striker: Mandeep Singh
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 5.1:
#         batsman: Mandeep Singh
#         bowler: Rashid Khan
#         non_striker: CH Gayle
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 5.2:
#         batsman: Mandeep Singh
#         bowler: Rashid Khan
#         non_striker: CH Gayle
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 5.3:
#         batsman: Mandeep Singh
#         bowler: Rashid Khan
#         non_striker: CH Gayle
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 5.4:
#         batsman: Mandeep Singh
#         bowler: Rashid Khan
#         non_striker: CH Gayle
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           kind: bowled
#           player_out: Mandeep Singh
#     - 5.5:
#         batsman: TM Head
#         bowler: Rashid Khan
#         non_striker: CH Gayle
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 5.6:
#         batsman: TM Head
#         bowler: Rashid Khan
#         non_striker: CH Gayle
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 6.1:
#         batsman: CH Gayle
#         bowler: DJ Hooda
#         non_striker: TM Head
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 6.2:
#         batsman: CH Gayle
#         bowler: DJ Hooda
#         non_striker: TM Head
#         runs:
#           batsman: 6
#           extras: 0
#           total: 6
#     - 6.3:
#         batsman: CH Gayle
#         bowler: DJ Hooda
#         non_striker: TM Head
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           fielders:
#           - DA Warner
#           kind: caught
#           player_out: CH Gayle
#     - 6.4:
#         batsman: TM Head
#         bowler: DJ Hooda
#         non_striker: KM Jadhav
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 6.5:
#         batsman: TM Head
#         bowler: DJ Hooda
#         non_striker: KM Jadhav
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 6.6:
#         batsman: KM Jadhav
#         bowler: DJ Hooda
#         non_striker: TM Head
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 7.1:
#         batsman: TM Head
#         bowler: Rashid Khan
#         non_striker: KM Jadhav
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 7.2:
#         batsman: TM Head
#         bowler: Rashid Khan
#         non_striker: KM Jadhav
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 7.3:
#         batsman: TM Head
#         bowler: Rashid Khan
#         non_striker: KM Jadhav
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 7.4:
#         batsman: KM Jadhav
#         bowler: Rashid Khan
#         non_striker: TM Head
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 7.5:
#         batsman: TM Head
#         bowler: Rashid Khan
#         non_striker: KM Jadhav
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 7.6:
#         batsman: KM Jadhav
#         bowler: Rashid Khan
#         non_striker: TM Head
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 8.1:
#         batsman: TM Head
#         bowler: BCJ Cutting
#         non_striker: KM Jadhav
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 8.2:
#         batsman: KM Jadhav
#         bowler: BCJ Cutting
#         extras:
#           wides: 1
#         non_striker: TM Head
#         runs:
#           batsman: 0
#           extras: 1
#           total: 1
#     - 8.3:
#         batsman: KM Jadhav
#         bowler: BCJ Cutting
#         non_striker: TM Head
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 8.4:
#         batsman: KM Jadhav
#         bowler: BCJ Cutting
#         non_striker: TM Head
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 8.5:
#         batsman: TM Head
#         bowler: BCJ Cutting
#         non_striker: KM Jadhav
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 8.6:
#         batsman: KM Jadhav
#         bowler: BCJ Cutting
#         non_striker: TM Head
#         runs:
#           batsman: 6
#           extras: 0
#           total: 6
#     - 8.7:
#         batsman: KM Jadhav
#         bowler: BCJ Cutting
#         non_striker: TM Head
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 9.1:
#         batsman: KM Jadhav
#         bowler: MC Henriques
#         extras:
#           noballs: 1
#         non_striker: TM Head
#         runs:
#           batsman: 1
#           extras: 1
#           total: 2
#     - 9.2:
#         batsman: TM Head
#         bowler: MC Henriques
#         non_striker: KM Jadhav
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 9.3:
#         batsman: TM Head
#         bowler: MC Henriques
#         non_striker: KM Jadhav
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 9.4:
#         batsman: KM Jadhav
#         bowler: MC Henriques
#         non_striker: TM Head
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 9.5:
#         batsman: TM Head
#         bowler: MC Henriques
#         non_striker: KM Jadhav
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 9.6:
#         batsman: TM Head
#         bowler: MC Henriques
#         non_striker: KM Jadhav
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 9.7:
#         batsman: KM Jadhav
#         bowler: MC Henriques
#         non_striker: TM Head
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 10.1:
#         batsman: TM Head
#         bowler: A Nehra
#         non_striker: KM Jadhav
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 10.2:
#         batsman: KM Jadhav
#         bowler: A Nehra
#         extras:
#           wides: 1
#         non_striker: TM Head
#         runs:
#           batsman: 0
#           extras: 1
#           total: 1
#     - 10.3:
#         batsman: KM Jadhav
#         bowler: A Nehra
#         non_striker: TM Head
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 10.4:
#         batsman: TM Head
#         bowler: A Nehra
#         non_striker: KM Jadhav
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 10.5:
#         batsman: KM Jadhav
#         bowler: A Nehra
#         non_striker: TM Head
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 10.6:
#         batsman: KM Jadhav
#         bowler: A Nehra
#         non_striker: TM Head
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 10.7:
#         batsman: KM Jadhav
#         bowler: A Nehra
#         non_striker: TM Head
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 11.1:
#         batsman: KM Jadhav
#         bowler: MC Henriques
#         non_striker: TM Head
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 11.2:
#         batsman: TM Head
#         bowler: MC Henriques
#         non_striker: KM Jadhav
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 11.3:
#         batsman: TM Head
#         bowler: MC Henriques
#         non_striker: KM Jadhav
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 11.4:
#         batsman: KM Jadhav
#         bowler: MC Henriques
#         non_striker: TM Head
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#         wicket:
#           fielders:
#           - BCJ Cutting
#           kind: run out
#           player_out: KM Jadhav
#     - 11.5:
#         batsman: SR Watson
#         bowler: MC Henriques
#         non_striker: TM Head
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 11.6:
#         batsman: TM Head
#         bowler: MC Henriques
#         non_striker: SR Watson
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 12.1:
#         batsman: TM Head
#         bowler: Rashid Khan
#         non_striker: SR Watson
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 12.2:
#         batsman: SR Watson
#         bowler: Rashid Khan
#         non_striker: TM Head
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 12.3:
#         batsman: SR Watson
#         bowler: Rashid Khan
#         non_striker: TM Head
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 12.4:
#         batsman: TM Head
#         bowler: Rashid Khan
#         non_striker: SR Watson
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 12.5:
#         batsman: TM Head
#         bowler: Rashid Khan
#         non_striker: SR Watson
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           fielders:
#           - Yuvraj Singh
#           kind: caught
#           player_out: TM Head
#     - 12.6:
#         batsman: SR Watson
#         bowler: Rashid Khan
#         non_striker: Sachin Baby
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 13.1:
#         batsman: Sachin Baby
#         bowler: Bipul Sharma
#         non_striker: SR Watson
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 13.2:
#         batsman: Sachin Baby
#         bowler: Bipul Sharma
#         non_striker: SR Watson
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 13.3:
#         batsman: SR Watson
#         bowler: Bipul Sharma
#         non_striker: Sachin Baby
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 13.4:
#         batsman: Sachin Baby
#         bowler: Bipul Sharma
#         non_striker: SR Watson
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           fielders:
#           - MC Henriques
#           kind: caught
#           player_out: Sachin Baby
#     - 13.5:
#         batsman: SR Watson
#         bowler: Bipul Sharma
#         non_striker: STR Binny
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 13.6:
#         batsman: STR Binny
#         bowler: Bipul Sharma
#         non_striker: SR Watson
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 14.1:
#         batsman: STR Binny
#         bowler: Rashid Khan
#         non_striker: SR Watson
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 14.2:
#         batsman: SR Watson
#         bowler: Rashid Khan
#         non_striker: STR Binny
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 14.3:
#         batsman: STR Binny
#         bowler: Rashid Khan
#         non_striker: SR Watson
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 14.4:
#         batsman: STR Binny
#         bowler: Rashid Khan
#         non_striker: SR Watson
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 14.5:
#         batsman: STR Binny
#         bowler: Rashid Khan
#         non_striker: SR Watson
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 14.6:
#         batsman: SR Watson
#         bowler: Rashid Khan
#         non_striker: STR Binny
#         runs:
#           batsman: 6
#           extras: 0
#           total: 6
#     - 15.1:
#         batsman: STR Binny
#         bowler: BCJ Cutting
#         non_striker: SR Watson
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 15.2:
#         batsman: STR Binny
#         bowler: BCJ Cutting
#         non_striker: SR Watson
#         runs:
#           batsman: 6
#           extras: 0
#           total: 6
#     - 15.3:
#         batsman: STR Binny
#         bowler: BCJ Cutting
#         non_striker: SR Watson
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 15.4:
#         batsman: SR Watson
#         bowler: BCJ Cutting
#         non_striker: STR Binny
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 15.5:
#         batsman: SR Watson
#         bowler: BCJ Cutting
#         non_striker: STR Binny
#         runs:
#           batsman: 4
#           extras: 0
#           total: 4
#     - 15.6:
#         batsman: SR Watson
#         bowler: BCJ Cutting
#         non_striker: STR Binny
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 16.1:
#         batsman: SR Watson
#         bowler: B Kumar
#         non_striker: STR Binny
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 16.2:
#         batsman: STR Binny
#         bowler: B Kumar
#         non_striker: SR Watson
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 16.3:
#         batsman: SR Watson
#         bowler: B Kumar
#         non_striker: STR Binny
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 16.4:
#         batsman: SR Watson
#         bowler: B Kumar
#         non_striker: STR Binny
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 16.5:
#         batsman: STR Binny
#         bowler: B Kumar
#         non_striker: SR Watson
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           fielders:
#           - Yuvraj Singh
#           kind: caught
#           player_out: STR Binny
#     - 16.6:
#         batsman: S Aravind
#         bowler: B Kumar
#         non_striker: SR Watson
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 17.1:
#         batsman: SR Watson
#         bowler: A Nehra
#         non_striker: S Aravind
#         runs:
#           batsman: 2
#           extras: 0
#           total: 2
#     - 17.2:
#         batsman: SR Watson
#         bowler: A Nehra
#         non_striker: S Aravind
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 17.3:
#         batsman: SR Watson
#         bowler: A Nehra
#         non_striker: S Aravind
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           fielders:
#           - MC Henriques
#           kind: caught
#           player_out: SR Watson
#     - 17.4:
#         batsman: S Aravind
#         bowler: A Nehra
#         non_striker: TS Mills
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           kind: bowled
#           player_out: S Aravind
#     - 17.5:
#         batsman: YS Chahal
#         bowler: A Nehra
#         non_striker: TS Mills
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 17.6:
#         batsman: YS Chahal
#         bowler: A Nehra
#         non_striker: TS Mills
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 18.1:
#         batsman: TS Mills
#         bowler: B Kumar
#         extras:
#           legbyes: 1
#         non_striker: YS Chahal
#         runs:
#           batsman: 0
#           extras: 1
#           total: 1
#     - 18.2:
#         batsman: YS Chahal
#         bowler: B Kumar
#         non_striker: TS Mills
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 18.3:
#         batsman: YS Chahal
#         bowler: B Kumar
#         non_striker: TS Mills
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 18.4:
#         batsman: TS Mills
#         bowler: B Kumar
#         non_striker: YS Chahal
#         runs:
#           batsman: 6
#           extras: 0
#           total: 6
#     - 18.5:
#         batsman: TS Mills
#         bowler: B Kumar
#         non_striker: YS Chahal
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           fielders:
#           - DA Warner
#           kind: caught
#           player_out: TS Mills
#     - 18.6:
#         batsman: YS Chahal
#         bowler: B Kumar
#         non_striker: A Choudhary
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 19.1:
#         batsman: YS Chahal
#         bowler: BCJ Cutting
#         non_striker: A Choudhary
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#     - 19.2:
#         batsman: YS Chahal
#         bowler: BCJ Cutting
#         non_striker: A Choudhary
#         runs:
#           batsman: 1
#           extras: 0
#           total: 1
#     - 19.3:
#         batsman: A Choudhary
#         bowler: BCJ Cutting
#         non_striker: YS Chahal
#         runs:
#           batsman: 6
#           extras: 0
#           total: 6
#     - 19.4:
#         batsman: A Choudhary
#         bowler: BCJ Cutting
#         non_striker: YS Chahal
#         runs:
#           batsman: 0
#           extras: 0
#           total: 0
#         wicket:
#           fielders:
#           - CJ Jordan (sub)
#           kind: run out
#           player_out: YS Chahal
#     team: Royal Challengers Bangalore
# meta:
#   created: 2017-04-06
#   data_version: 0.9
#   revision: 1
