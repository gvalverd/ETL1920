# %% [markdown]
# # Examen ETL: SPARK 12+1/02

# %% [markdown]
# * Autor: Beltrán Aller López
# * Fecha: 02/12/2019
# * Asignatura: ETL

# %% [markdown]
# Se podrá utilizar toda la información que se encuentra en el campus.
#
# Se va a trabajar sobre varios ficheros de datos:
#
# Usuarios: id_usuario::sexo::edad::id_profesion::codigo_postal
#
# Peliculas: id_pelicula::titulo (año)::tipo1|tipo2|tipo3
#
# Ratings: id_pelicula::id_usuario::puntuacion::fecha_timestamp
#
# A cada una de las preguntas hay que responder explicando brevemente que se pretende hacer antes de lanzar el código.
#
# Al documento lo llamareís con vuestro nombre y apellido. Debeís enviarlo a mi correo de CUNEF antes del final del examen.
#
# El lenguaje para trabajar con Spark podrá ser python o R indistintamente.

# %%
# Nota: Carga de las puntuaciones
# Función para parsear la fecha

from datetime import datetime
dateparse = lambda x: datetime.fromtimestamp(float(x))

# %% [markdown]
# ## Primera tarea: Inicializar spark context y cargar los datos desde los ficheros.

# %% [markdown]
# En primer lugar inicializo el contexto spark, para ello importo la librería necesaria.

# %%
from pyspark import SparkContext # importo la libreria
sc = SparkContext() # inicializo el contexto spark

# %% [markdown]
# A continuación procedo a cargar los ficheros y verificar que la carga se realiza de forma adecuada.

# %% [markdown]
# ### Movies

# %% [markdown]
# El primer fichero que cargaré será movies.dat.txt.

# %%
movies_file = "../data/movies.dat.txt" 
movies_data = sc.textFile(movies_file)

# %% [markdown]
# * Extraigo una muestra para ver que formato tiene.

# %%
movies_data.take(3)
# Out:
# ["1::Toy Story (1995)::Animation|Children's|Comedy",
#  "2::Jumanji (1995)::Adventure|Children's|Fantasy",
#  '3::Grumpier Old Men (1995)::Comedy|Romance']

# %% [markdown]
# * Realizo un conteo para comprobar que se ha cargado por completo.

# %%
movies_data.count()
# Out:
# 3883

# %% [markdown]
# El fichero presenta las siguientes características:
# * Posee 3883 registros.
# * Cada registro es de la forma: "1 ó + dígitos :: cadena de texto (separada por espacios en blanco) y (4 dígitos) :: Cadena de texto separada por |".

# %% [markdown]
# Dejo el fichero ya dividido por los ::

# %%
movies_splitted = movies_data.map(lambda x: x.split("::"))

# %%
movies_splitted.take(1)
# Out:
# [['1', 'Toy Story (1995)', "Animation|Children's|Comedy"]]

# %% [markdown]
# ### Ratings

# %% [markdown]
# El siguiente fichero será ratings.dat.txt.

# %%
ratings_file = "../data/ratings.dat.txt" 
ratings_data = sc.textFile(ratings_file)

# %% [markdown]
# * Observo una muestra para ver el formato.

# %%
ratings_data.take(3)
# Out:
# ['1::1193::5::978300760', '1::661::3::978302109', '1::914::3::978301968']

# %% [markdown]
# * Cuento el número de registros del fichero.

# %%
ratings_data.count()
# Out:
# 1000209

# %% [markdown]
# El fichero presenta las siguientes características:
# * Posee 1.000.209 registros.
# * Cada registro es de la forma: '1 o + dígitos :: 4 dígitos :: dígito :: 9 dígitos'.

# %% [markdown]
# Dejo el fichero ya dividido por los ::

# %%
ratings_splitted = ratings_data.map(lambda x: x.split("::")).map(lambda x: [int(x[0]),int(x[1]),int(x[2]),datetime.fromtimestamp(float(x[3])).year])

# %%
ratings_splitted.take(1)
# Out:
# [[1, 1193, 5, 2000]]

# %% [markdown]
# ### Users

# %% [markdown]
# El último fichero es users.dat.txt.

# %%
users_file = "../data/users.dat.txt" 
users_data = sc.textFile(users_file)

# %% [markdown]
# * Observo una muestra.

# %%
users_data.take(3)
# Out:
# ['1::F::1::10::48067', '2::M::56::16::70072', '3::M::25::15::55117']

# %% [markdown]
# * Realizo el conteo del número de registros.

# %%
users_data.count()
# Out:
# 6040

# %% [markdown]
# El fichero presenta las siguientes características:
# * Posee un total de 6040 registros.
# * Tiene un formato:'1 ó + dígitos :: caracter :: 1 ó + dígitos :: 2 dígitos :: 5 dígitos'

# %% [markdown]
# Dejo el fichero ya dividido por los ::

# %%
users_splitted = users_data.map(lambda x: x.split("::"))

# %%
users_splitted.take(1)
# Out:
# [['1', 'F', '1', '10', '48067']]

# %% [markdown]
# ## Segunda tarea: Media de puntuaciones globales por año. ¿Hay algún año significativamente distinto?

# %%
ratings_splitted.map(lambda x: x[3]).distinct().collect()
# Out:
# [2000, 2001, 2002, 2003]

# %% [markdown]
# #### Año 2000

# %% [markdown]
# Saco la puntuación de cada peli del año 2000.

# %%
anno_2000 = ratings_splitted.filter(lambda x: x[3] == 2000).map(lambda x: (x[0],x[2])).reduceByKey(lambda a,b:a + b)

# %%
anno_2000.collect()
# Out:
# [(1, 167),
#  (2, 479),
#  (3, 199),
#  (4, 88),
#  (5, 623),
#  (6, 277),
#  (7, 134),
#  (8, 540),
#  (9, 396),
#  (10, 1216),
#  (11, 208),
#  (12, 88),
#  (13, 366),
#  (14, 83),
#  (15, 663),
#  (16, 106),
#  (17, 860),
#  (18, 1113),
#  (19, 365),
#  (20, 57),
#  (21, 64),
#  (22, 750),
#  (23, 18),
#  (24, 516),
#  (25, 290),
#  (26, 1173),
#  (27, 292),
#  (28, 348),
#  (29, 387),
#  (30, 150),
#  (31, 444),
#  (32, 174),
#  (33, 709),
#  (34, 634),
#  (35, 701),
#  (36, 1164),
#  (37, 196),
#  (38, 358),
#  (39, 221),
#  (40, 331),
#  (41, 87),
#  (42, 864),
#  (43, 99),
#  (44, 458),
#  (45, 875),
#  (46, 173),
#  (47, 86),
#  (48, 1832),
#  (49, 357),
#  (50, 132),
#  (51, 153),
#  (52, 281),
#  (53, 2898),
#  (54, 161),
#  (55, 103),
#  (56, 266),
#  (57, 186),
#  (58, 1736),
#  (59, 329),
#  (60, 239),
#  (61, 100),
#  (62, 1776),
#  (63, 277),
#  (64, 112),
#  (65, 163),
#  (66, 100),
#  (67, 275),
#  (68, 155),
#  (69, 270),
#  (70, 200),
#  (71, 109),
#  (72, 159),
#  (73, 682),
#  (74, 20),
#  (75, 583),
#  (76, 284),
#  (77, 115),
#  (78, 161),
#  (79, 113),
#  (80, 182),
#  (81, 380),
#  (82, 456),
#  (83, 354),
#  (84, 119),
#  (85, 60),
#  (86, 118),
#  (87, 166),
#  (88, 282),
#  (89, 39),
#  (90, 35),
#  (91, 207),
#  (92, 453),
#  (93, 654),
#  (94, 81),
#  (95, 356),
#  (96, 14),
#  (97, 680),
#  (98, 76),
#  (99, 48),
#  (100, 230),
#  (101, 496),
#  (102, 27),
#  (103, 466),
#  (104, 109),
#  (105, 262),
#  (106, 189),
#  (107, 453),
#  (108, 116),
#  (109, 324),
#  (110, 260),
#  (111, 343),
#  (112, 251),
#  (113, 238),
#  (114, 304),
#  (115, 146),
#  (116, 135),
#  (117, 1663),
#  (118, 844),
#  (119, 372),
#  (120, 228),
#  (121, 318),
#  (122, 139),
#  (123, 1771),
#  (124, 48),
#  (125, 291),
#  (126, 204),
#  (127, 389),
#  (128, 96),
#  (129, 636),
#  (130, 582),
#  (131, 940),
#  (132, 353),
#  (133, 620),
#  (134, 440),
#  (135, 256),
#  (136, 1162),
#  (137, 191),
#  (138, 292),
#  (139, 951),
#  (140, 34),
#  (141, 85),
#  (142, 119),
#  (143, 241),
#  (144, 111),
#  (145, 117),
#  (146, 660),
#  (147, 655),
#  (148, 1359),
#  (149, 1703),
#  (150, 874),
#  (151, 297),
#  (152, 99),
#  (153, 62),
#  (154, 136),
#  (155, 285),
#  (156, 627),
#  (157, 1460),
#  (158, 88),
#  (160, 48),
#  (161, 1328),
#  (162, 176),
#  (163, 1122),
#  (164, 29),
#  (165, 438),
#  (166, 1483),
#  (167, 170),
#  (168, 100),
#  (169, 1807),
#  (170, 347),
#  (171, 96),
#  (172, 83),
#  (173, 86),
#  (174, 354),
#  (175, 1253),
#  (176, 282),
#  (177, 181),
#  (178, 442),
#  (179, 292),
#  (180, 164),
#  (181, 1085),
#  (182, 318),
#  (183, 94),
#  (184, 27),
#  (185, 183),
#  (186, 519),
#  (187, 1703),
#  (188, 13),
#  (189, 124),
#  (190, 566),
#  (191, 100),
#  (192, 1485),
#  (193, 573),
#  (194, 235),
#  (195, 1078),
#  (196, 130),
#  (197, 86),
#  (198, 1382),
#  (199, 1317),
#  (200, 89),
#  (201, 269),
#  (202, 2177),
#  (203, 291),
#  (204, 1084),
#  (205, 621),
#  (206, 92),
#  (207, 81),
#  (208, 248),
#  (209, 79),
#  (210, 443),
#  (211, 135),
#  (212, 424),
#  (213, 93),
#  (214, 525),
#  (215, 146),
#  (216, 2566),
#  (217, 74),
#  (218, 233),
#  (219, 120),
#  (220, 430),
#  (221, 94),
#  (222, 327),
#  (223, 881),
#  (224, 492),
#  (225, 1744),
#  (226, 75),
#  (227, 92),
#  (228, 95),
#  (229, 283),
#  (230, 733),
#  (231, 51),
#  (232, 321),
#  (233, 243),
#  (234, 97),
#  (235, 1458),
#  (236, 229),
#  (237, 305),
#  (238, 977),
#  (239, 100),
#  (240, 472),
#  (241, 226),
#  (242, 833),
#  (243, 119),
#  (244, 349),
#  (245, 2041),
#  (246, 116),
#  (247, 122),
#  (248, 122),
#  (249, 434),
#  (250, 75),
#  (251, 261),
#  (252, 241),
#  (253, 208),
#  (254, 87),
#  (255, 980),
#  (256, 366),
#  (257, 236),
#  (258, 539),
#  (259, 370),
#  (260, 510),
#  (261, 1266),
#  (262, 353),
#  (263, 337),
#  (264, 1217),
#  (265, 411),
#  (266, 226),
#  (267, 394),
#  (268, 886),
#  (269, 114),
#  (270, 489),
#  (271, 689),
#  (272, 1761),
#  (273, 697),
#  (274, 628),
#  (275, 378),
#  (276, 81),
#  (277, 82),
#  (278, 785),
#  (279, 56),
#  (280, 197),
#  (281, 432),
#  (282, 102),
#  (283, 134),
#  (284, 1423),
#  (285, 495),
#  (286, 167),
#  (287, 382),
#  (288, 257),
#  (289, 289),
#  (290, 109),
#  (291, 422),
#  (292, 154),
#  (293, 657),
#  (294, 171),
#  (295, 719),
#  (296, 349),
#  (297, 356),
#  (298, 106),
#  (299, 313),
#  (300, 1041),
#  (301, 1357),
#  (302, 1948),
#  (303, 805),
#  (304, 96),
#  (305, 402),
#  (306, 254),
#  (307, 836),
#  (308, 942),
#  (309, 497),
#  (310, 714),
#  (311, 66),
#  (312, 213),
#  (313, 105),
#  (314, 924),
#  (315, 85),
#  (316, 317),
#  (317, 80),
#  (318, 83),
#  (319, 1733),
#  (320, 89),
#  (321, 714),
#  (322, 178),
#  (323, 447),
#  (324, 253),
#  (325, 174),
#  (326, 1016),
#  (327, 866),
#  (328, 188),
#  (329, 1498),
#  (330, 246),
#  (331, 628),
#  (332, 154),
#  (333, 24),
#  (334, 241),
#  (335, 370),
#  (336, 461),
#  (337, 698),
#  (338, 728),
#  (339, 499),
#  (340, 381),
#  (341, 84),
#  (342, 454),
#  (343, 88),
#  (344, 266),
#  (345, 110),
#  (346, 1219),
#  (347, 384),
#  (348, 378),
#  (350, 252),
#  (351, 372),
#  (352, 3027),
#  (353, 94),
#  (354, 208),
#  (355, 966),
#  (356, 64),
#  (357, 191),
#  (358, 277),
#  (359, 189),
#  (360, 244),
#  (361, 92),
#  (362, 87),
#  (363, 161),
#  (364, 88),
#  (365, 157),
#  (366, 636),
#  (367, 119),
#  (368, 989),
#  (369, 278),
#  (370, 225),
#  (371, 273),
#  (372, 412),
#  (373, 96),
#  (374, 229),
#  (375, 25),
#  (376, 38),
#  (377, 531),
#  (378, 137),
#  (379, 271),
#  (380, 514),
#  (381, 144),
#  (382, 219),
#  (383, 75),
#  (384, 79),
#  (385, 542),
#  (386, 864),
#  (387, 233),
#  (388, 229),
#  (389, 260),
#  (390, 786),
#  (391, 273),
#  (392, 1552),
#  (393, 265),
#  (394, 127),
#  (395, 83),
#  (396, 616),
#  (397, 132),
#  (398, 14),
#  (399, 133),
#  (400, 155),
#  (401, 302),
#  (402, 981),
#  (403, 1014),
#  (404, 124),
#  (405, 169),
#  (406, 486),
#  (407, 110),
#  (408, 534),
#  (409, 1163),
#  (410, 381),
#  (411, 586),
#  (412, 2020),
#  (413, 436),
#  (414, 175),
#  (415, 1050),
#  (416, 233),
#  (417, 89),
#  (418, 181),
#  (419, 115),
#  (420, 245),
#  (421, 85),
#  (422, 33),
#  (423, 160),
#  (424, 1407),
#  (425, 692),
#  (426, 898),
#  (427, 111),
#  (428, 195),
#  (429, 1158),
#  (430, 250),
#  (431, 305),
#  (432, 218),
#  (433, 156),
#  (434, 173),
#  (435, 506),
#  (436, 510),
#  (437, 224),
#  (438, 1473),
#  (439, 258),
#  (440, 104),
#  (441, 186),
#  (442, 226),
#  (443, 130),
#  (444, 480),
#  (445, 949),
#  (446, 247),
#  (447, 179),
#  (448, 79),
#  (449, 201),
#  (450, 214),
#  (451, 943),
#  (452, 585),
#  (453, 1332),
#  (454, 550),
#  (455, 105),
#  (456, 533),
#  (457, 880),
#  (458, 152),
#  (459, 118),
#  (460, 158),
#  (461, 1651),
#  (462, 431),
#  (463, 369),
#  (464, 296),
#  (465, 131),
#  (466, 824),
#  (467, 221),
#  (468, 97),
#  (469, 212),
#  (470, 259),
#  (471, 381),
#  (472, 181),
#  (473, 204),
#  (474, 1075),
#  (475, 946),
#  (476, 1654),
#  (477, 756),
#  (478, 178),
#  (479, 356),
#  (480, 311),
#  (481, 732),
#  (482, 2454),
#  (483, 85),
#  (484, 127),
#  (485, 182),
#  (486, 158),
#  (487, 84),
#  (488, 89),
#  (489, 80),
#  (490, 290),
#  (491, 92),
#  (492, 126),
#  (493, 608),
#  (494, 794),
#  (495, 167),
#  (496, 202),
#  (497, 86),
#  (498, 628),
#  (499, 791),
#  (500, 312),
#  (501, 229),
#  (502, 98),
#  (503, 129),
#  (504, 411),
#  (505, 485),
#  (506, 308),
#  (507, 34),
#  (508, 495),
#  (509, 2396),
#  (510, 379),
#  (511, 101),
#  (512, 142),
#  (513, 491),
#  (514, 264),
#  (515, 604),
#  (516, 862),
#  (517, 658),
#  (518, 27),
#  (519, 120),
#  (520, 1191),
#  (521, 176),
#  (522, 223),
#  (523, 406),
#  (524, 3666),
#  (525, 161),
#  (526, 226),
#  (527, 102),
#  (528, 860),
#  (529, 440),
#  (530, 420),
#  (531, 22),
#  (532, 166),
#  (533, 1974),
#  (534, 386),
#  (535, 75),
#  (536, 828),
#  (537, 422),
#  (538, 214),
#  (539, 518),
#  (540, 126),
#  (541, 606),
#  (542, 128),
#  (543, 2737),
#  (544, 306),
#  (545, 101),
#  (546, 711),
#  (547, 301),
#  (548, 365),
#  (549, 4183),
#  (550, 3460),
#  (551, 871),
#  (552, 365),
#  (553, 266),
#  (554, 151),
#  (555, 145),
#  (556, 812),
#  (557, 225),
#  (558, 1071),
#  (559, 63),
#  (560, 534),
#  (561, 134),
#  (562, 137),
#  (563, 935),
#  (564, 200),
#  (565, 86),
#  (566, 1403),
#  (567, 330),
#  (568, 111),
#  (569, 440),
#  (570, 789),
#  (571, 541),
#  (572, 61),
#  (573, 143),
#  (574, 86),
#  (575, 596),
#  (576, 209),
#  (577, 709),
#  (578, 111),
#  (579, 266),
#  (580, 154),
#  (581, 176),
#  (582, 47),
#  (583, 416),
#  (584, 96),
#  (585, 513),
#  (586, 157),
#  (587, 1121),
#  (588, 1274),
#  (589, 108),
#  (590, 687),
#  (591, 782),
#  (592, 101),
#  (593, 345),
#  (594, 683),
#  (595, 391),
#  (596, 124),
#  (597, 255),
#  (598, 126),
#  (599, 104),
#  (600, 84),
#  (601, 1175),
#  (602, 523),
#  (603, 222),
#  (604, 888),
#  (605, 494),
#  (606, 133),
#  (607, 104),
#  (608, 483),
#  (609, 153),
#  (610, 439),
#  (611, 506),
#  (612, 175),
#  (613, 380),
#  (614, 207),
#  (615, 388),
#  (616, 174),
#  (617, 94),
#  (618, 135),
#  (619, 86),
#  (620, 595),
#  (621, 730),
#  (622, 223),
#  (623, 507),
#  (624, 866),
#  (625, 180),
#  (626, 287),
#  (627, 114),
#  (628, 203),
#  (629, 799),
#  (630, 502),
#  (631, 1184),
#  (632, 129),
#  (633, 95),
#  (634, 269),
#  (635, 439),
#  (636, 349),
#  (637, 1416),
#  (638, 476),
#  (639, 766),
#  (640, 91),
#  (641, 241),
#  (642, 111),
#  (643, 190),
#  (644, 337),
#  (645, 197),
#  (646, 966),
#  (647, 717),
#  (648, 287),
#  (649, 257),
#  (650, 111),
#  (651, 1727),
#  (652, 381),
#  (653, 87),
#  (654, 635),
#  (655, 1126),
#  (656, 685),
#  (657, 237),
#  (658, 288),
#  (659, 407),
#  (660, 2121),
#  (661, 330),
#  (662, 399),
#  (663, 401),
#  (664, 636),
#  (665, 70),
#  (666, 401),
#  (667, 371),
#  (668, 129),
#  (669, 1612),
#  (670, 292),
#  (671, 464),
#  (672, 182),
#  (673, 1262),
#  (674, 338),
#  (675, 139),
#  (676, 1220),
#  (677, 798),
#  (678, 253),
#  (679, 322),
#  (680, 125),
#  (681, 161),
#  (682, 355),
#  (683, 104),
#  (684, 148),
#  (685, 453),
#  (686, 102),
#  (687, 1102),
#  (688, 135),
#  (689, 458),
#  (690, 776),
#  (691, 98),
#  (692, 1237),
#  (693, 272),
#  (694, 145),
#  (695, 671),
#  (696, 1275),
#  (697, 475),
#  (698, 432),
#  (699, 1531),
#  (700, 124),
#  (701, 92),
#  (702, 1582),
#  (703, 82),
#  (704, 228),
#  (705, 445),
#  (706, 537),
#  (707, 185),
#  (708, 77),
#  (709, 232),
#  (710, 2493),
#  (711, 513),
#  (712, 980),
#  (713, 834),
#  (714, 1752),
#  (715, 316),
#  (716, 819),
#  (717, 123),
#  (718, 638),
#  (719, 98),
#  (720, 678),
#  (721, 1942),
#  (722, 215),
#  (723, 92),
#  (724, 572),
#  (725, 340),
#  (726, 287),
#  (727, 398),
#  (728, 553),
#  (729, 515),
#  (730, 200),
#  (731, 2426),
#  (732, 600),
#  (733, 475),
#  (734, 164),
#  (735, 1411),
#  (736, 269),
#  (737, 351),
#  (738, 109),
#  (739, 553),
#  (740, 157),
#  (741, 256),
#  (742, 166),
#  (743, 328),
#  (744, 1001),
#  (745, 66),
#  (746, 1082),
#  (747, 115),
#  (748, 322),
#  (749, 1269),
#  (750, 242),
#  (751, 97),
#  (752, 1900),
#  (753, 548),
#  (754, 415),
#  (755, 26),
#  (756, 139),
#  (757, 1500),
#  (758, 116),
#  (759, 348),
#  (760, 273),
#  (761, 91),
#  (762, 171),
#  (763, 97),
#  (764, 629),
#  (765, 1437),
#  (766, 185),
#  (767, 515),
#  (768, 213),
#  (769, 256),
#  (770, 1943),
#  (771, 98),
#  (772, 341),
#  (773, 176),
#  (774, 637),
#  (775, 92),
#  (776, 388),
#  (777, 1282),
#  (778, 617),
#  (779, 160),
#  (780, 1770),
#  (781, 742),
#  (782, 79),
#  (783, 394),
#  (784, 122),
#  (785, 343),
#  (786, 256),
#  (787, 395),
#  (788, 691),
#  (789, 334),
#  (790, 100),
#  (791, 149),
#  (792, 301),
#  (793, 523),
#  (794, 170),
#  (795, 465),
#  (796, 1288),
#  (797, 335),
#  (798, 1030),
#  (799, 144),
#  (800, 927),
#  (801, 1043),
#  (802, 1993),
#  (803, 193),
#  (804, 144),
#  (805, 280),
#  (806, 275),
#  (807, 131),
#  (808, 859),
#  (809, 379),
#  (810, 481),
#  (811, 272),
#  (812, 344),
#  (813, 224),
#  (814, 146),
#  (815, 118),
#  (816, 721),
#  (817, 1596),
#  (818, 637),
#  (819, 206),
#  (820, 355),
#  (821, 62),
#  (822, 995),
#  (823, 468),
#  (824, 1123),
#  (825, 152),
#  (826, 115),
#  (827, 17),
#  (828, 396),
#  (829, 388),
#  (830, 629),
#  (831, 234),
#  (832, 612),
#  (833, 85),
#  (834, 208),
#  (835, 77),
#  (836, 168),
#  (837, 225),
#  (838, 706),
#  (839, 1304),
#  (840, 521),
#  (841, 93),
#  (842, 142),
#  (843, 497),
#  (844, 290),
#  (845, 207),
#  (846, 677),
#  (847, 224),
#  (848, 230),
#  (849, 382),
#  (850, 1973),
#  (851, 273),
#  (852, 140),
#  (853, 428),
#  (854, 1532),
#  (855, 2150),
#  (856, 131),
#  (857, 292),
#  (858, 796),
#  (859, 528),
#  (860, 133),
#  (861, 315),
#  (862, 422),
#  (863, 262),
#  (864, 559),
#  (865, 160),
#  (866, 120),
#  (867, 161),
#  (868, 270),
#  (869, 2244),
#  (870, 130),
#  (871, 168),
#  (872, 299),
#  (873, 661),
#  (874, 22),
#  (875, 343),
#  (876, 425),
#  (877, 2094),
#  (878, 203),
#  (879, 161),
#  (880, 402),
#  (881, 1677),
#  (882, 323),
#  (883, 123),
#  (884, 83),
#  (885, 265),
#  (886, 127),
#  (887, 337),
#  (888, 272),
#  (889, 4312),
#  (890, 389),
#  (891, 835),
#  (892, 133),
#  (893, 352),
#  (894, 311),
#  (895, 253),
#  (896, 255),
#  (897, 578),
#  (898, 98),
#  (899, 1115),
#  (900, 93),
#  (901, 119),
#  (902, 107),
#  (903, 256),
#  (904, 680),
#  (905, 466),
#  (906, 74),
#  (907, 83),
#  (908, 129),
#  (909, 277),
#  (910, 466),
#  (911, 1682),
#  (912, 160),
#  (913, 105),
#  (914, 261),
#  (915, 269),
#  (916, 217),
#  (917, 118),
#  (918, 426),
#  (919, 1283),
#  (920, 270),
#  (921, 584),
#  (922, 1229),
#  (923, 166),
#  (924, 794),
#  (925, 213),
#  (926, 260),
#  (927, 354),
#  (928, 917),
#  (929, 1270),
#  (930, 174),
#  (931, 633),
#  (932, 89),
#  (933, 230),
#  (934, 415),
#  (935, 1354),
#  (936, 309),
#  (937, 216),
#  (938, 120),
#  (939, 620),
#  (940, 415),
#  (941, 64),
#  (942, 101),
#  (943, 299),
#  (944, 173),
#  (945, 590),
#  (946, 142),
#  (947, 60),
#  (948, 1916),
#  (949, 1450),
#  (950, 163),
#  (951, 95),
#  (952, 627),
#  (953, 693),
#  (954, 476),
#  (955, 1210),
#  (956, 431),
#  (957, 1380),
#  (958, 617),
#  (959, 53),
#  (960, 504),
#  (961, 187),
#  (962, 204),
#  (963, 1242),
#  (964, 290),
#  (965, 317),
#  (966, 588),
#  (967, 322),
#  (968, 252),
#  (969, 107),
#  (970, 1404),
#  (971, 743),
#  (972, 118),
#  (973, 737),
#  (974, 224),
#  (975, 1317),
#  (976, 185),
#  (977, 903),
#  (978, 171),
#  (979, 48),
#  (980, 435),
#  (981, 702),
#  (982, 213),
#  (983, 321),
#  (984, 2434),
#  (985, 615),
#  (986, 83),
#  (987, 682),
#  (988, 281),
#  (989, 206),
#  (990, 362),
#  (991, 225),
#  (992, 106),
#  (993, 47),
#  (994, 162),
#  (995, 191),
#  (996, 1083),
#  (997, 114),
#  (998, 556),
#  (999, 1313),
#  (1000, 347),
#  (1001, 1341),
#  (1002, 273),
#  ...]

# %% [markdown]
# Tengo que saber el numero de veces que votaron esa peli.

# %%
num_votos_peli = ratings_splitted.filter(lambda x: x[3] == 2000).map(lambda x: (x[0],1)).reduceByKey(lambda a,b:a + b)

# %%
num_votos_peli.collect()
# Out:
# [(1, 40),
#  (2, 129),
#  (3, 51),
#  (4, 21),
#  (5, 198),
#  (6, 71),
#  (7, 31),
#  (8, 139),
#  (9, 106),
#  (10, 299),
#  (11, 55),
#  (12, 23),
#  (13, 108),
#  (14, 25),
#  (15, 200),
#  (16, 35),
#  (17, 211),
#  (18, 305),
#  (19, 97),
#  (20, 13),
#  (21, 22),
#  (22, 247),
#  (23, 6),
#  (24, 131),
#  (25, 76),
#  (26, 397),
#  (27, 70),
#  (28, 91),
#  (29, 108),
#  (30, 43),
#  (31, 119),
#  (32, 48),
#  (33, 196),
#  (34, 164),
#  (35, 198),
#  (36, 277),
#  (37, 53),
#  (38, 100),
#  (39, 62),
#  (40, 96),
#  (41, 25),
#  (42, 231),
#  (43, 24),
#  (44, 117),
#  (45, 297),
#  (46, 41),
#  (47, 22),
#  (48, 597),
#  (49, 97),
#  (50, 43),
#  (51, 40),
#  (52, 79),
#  (53, 684),
#  (54, 40),
#  (55, 25),
#  (56, 67),
#  (57, 64),
#  (58, 437),
#  (59, 93),
#  (60, 70),
#  (61, 36),
#  (62, 498),
#  (63, 84),
#  (64, 27),
#  (65, 36),
#  (66, 26),
#  (67, 64),
#  (68, 42),
#  (69, 65),
#  (70, 54),
#  (71, 29),
#  (72, 43),
#  (73, 202),
#  (74, 5),
#  (75, 147),
#  (76, 64),
#  (77, 39),
#  (78, 44),
#  (79, 31),
#  (80, 47),
#  (81, 86),
#  (82, 113),
#  (83, 99),
#  (84, 31),
#  (85, 20),
#  (86, 29),
#  (87, 59),
#  (88, 68),
#  (89, 10),
#  (90, 9),
#  (91, 44),
#  (92, 147),
#  (93, 220),
#  (94, 21),
#  (95, 99),
#  (96, 5),
#  (97, 152),
#  (98, 20),
#  (99, 14),
#  (100, 76),
#  (101, 106),
#  (102, 6),
#  (103, 115),
#  (104, 30),
#  (105, 61),
#  (106, 47),
#  (107, 121),
#  (108, 37),
#  (109, 81),
#  (110, 80),
#  (111, 92),
#  (112, 60),
#  (113, 68),
#  (114, 85),
#  (115, 38),
#  (116, 36),
#  (117, 504),
#  (118, 224),
#  (119, 105),
#  (120, 63),
#  (121, 72),
#  (122, 42),
#  (123, 518),
#  (124, 12),
#  (125, 71),
#  (126, 51),
#  (127, 96),
#  (128, 22),
#  (129, 158),
#  (130, 135),
#  (131, 274),
#  (132, 89),
#  (133, 164),
#  (134, 164),
#  (135, 70),
#  (136, 378),
#  (137, 55),
#  (138, 65),
#  (139, 245),
#  (140, 10),
#  (141, 23),
#  (142, 37),
#  (143, 68),
#  (144, 32),
#  (145, 39),
#  (146, 176),
#  (147, 187),
#  (148, 375),
#  (149, 422),
#  (150, 218),
#  (151, 82),
#  (152, 24),
#  (153, 15),
#  (154, 44),
#  (155, 96),
#  (156, 148),
#  (157, 397),
#  (158, 22),
#  (160, 14),
#  (161, 297),
#  (162, 43),
#  (163, 514),
#  (164, 7),
#  (165, 110),
#  (166, 404),
#  (167, 58),
#  (168, 26),
#  (169, 495),
#  (170, 87),
#  (171, 24),
#  (172, 23),
#  (173, 22),
#  (174, 97),
#  (175, 314),
#  (176, 78),
#  (177, 44),
#  (178, 115),
#  (179, 110),
#  (180, 42),
#  (181, 301),
#  (182, 83),
#  (183, 23),
#  (184, 7),
#  (185, 51),
#  (186, 122),
#  (187, 417),
#  (188, 5),
#  (189, 31),
#  (190, 153),
#  (191, 30),
#  (192, 487),
#  (193, 150),
#  (194, 59),
#  (195, 253),
#  (196, 32),
#  (197, 22),
#  (198, 368),
#  (199, 402),
#  (200, 26),
#  (201, 67),
#  (202, 670),
#  (203, 127),
#  (204, 315),
#  (205, 153),
#  (206, 30),
#  (207, 23),
#  (208, 66),
#  (209, 25),
#  (210, 110),
#  (211, 35),
#  (212, 110),
#  (213, 22),
#  (214, 166),
#  (215, 32),
#  (216, 794),
#  (217, 20),
#  (218, 77),
#  (219, 36),
#  (220, 102),
#  (221, 29),
#  (222, 80),
#  (223, 256),
#  (224, 140),
#  (225, 508),
#  (226, 21),
#  (227, 28),
#  (228, 24),
#  (229, 83),
#  (230, 179),
#  (231, 11),
#  (232, 90),
#  (233, 53),
#  (234, 23),
#  (235, 352),
#  (236, 62),
#  (237, 79),
#  (238, 258),
#  (239, 27),
#  (240, 143),
#  (241, 57),
#  (242, 260),
#  (243, 33),
#  (244, 85),
#  (245, 764),
#  (246, 29),
#  (247, 31),
#  (248, 29),
#  (249, 110),
#  (250, 20),
#  (251, 73),
#  (252, 60),
#  (253, 53),
#  (254, 23),
#  (255, 244),
#  (256, 95),
#  (257, 53),
#  (258, 145),
#  (259, 92),
#  (260, 154),
#  (261, 354),
#  (262, 106),
#  (263, 92),
#  (264, 443),
#  (265, 98),
#  (266, 50),
#  (267, 117),
#  (268, 261),
#  (269, 30),
#  (270, 115),
#  (271, 161),
#  (272, 482),
#  (273, 187),
#  (274, 148),
#  (275, 89),
#  (276, 23),
#  (277, 22),
#  (278, 198),
#  (279, 16),
#  (280, 50),
#  (281, 111),
#  (282, 29),
#  (283, 27),
#  (284, 471),
#  (285, 119),
#  (286, 43),
#  (287, 103),
#  (288, 56),
#  (289, 74),
#  (290, 33),
#  (291, 102),
#  (292, 41),
#  (293, 194),
#  (294, 49),
#  (295, 191),
#  (296, 97),
#  (297, 89),
#  (298, 27),
#  (299, 77),
#  (300, 249),
#  (301, 357),
#  (302, 681),
#  (303, 208),
#  (304, 27),
#  (305, 157),
#  (306, 64),
#  (307, 182),
#  (308, 265),
#  (309, 123),
#  (310, 210),
#  (311, 16),
#  (312, 57),
#  (313, 26),
#  (314, 250),
#  (315, 22),
#  (316, 77),
#  (317, 21),
#  (318, 21),
#  (319, 543),
#  (320, 21),
#  (321, 219),
#  (322, 40),
#  (323, 118),
#  (324, 76),
#  (325, 43),
#  (326, 308),
#  (327, 236),
#  (328, 62),
#  (329, 548),
#  (330, 59),
#  (331, 157),
#  (332, 36),
#  (333, 7),
#  (334, 61),
#  (335, 148),
#  (336, 107),
#  (337, 198),
#  (338, 197),
#  (339, 124),
#  (340, 108),
#  (341, 20),
#  (342, 123),
#  (343, 23),
#  (344, 90),
#  (345, 25),
#  (346, 283),
#  (347, 99),
#  (348, 100),
#  (350, 64),
#  (351, 99),
#  (352, 870),
#  (353, 24),
#  (354, 58),
#  (355, 286),
#  (356, 15),
#  (357, 58),
#  (358, 72),
#  (359, 49),
#  (360, 67),
#  (361, 26),
#  (362, 26),
#  (363, 43),
#  (364, 28),
#  (365, 47),
#  (366, 152),
#  (367, 28),
#  (368, 260),
#  (369, 87),
#  (370, 60),
#  (371, 78),
#  (372, 94),
#  (373, 27),
#  (374, 52),
#  (375, 7),
#  (376, 8),
#  (377, 136),
#  (378, 39),
#  (379, 64),
#  (380, 138),
#  (381, 35),
#  (382, 54),
#  (383, 21),
#  (384, 22),
#  (385, 137),
#  (386, 260),
#  (387, 64),
#  (388, 59),
#  (389, 73),
#  (390, 214),
#  (391, 74),
#  (392, 448),
#  (393, 74),
#  (394, 38),
#  (395, 23),
#  (396, 173),
#  (397, 34),
#  (398, 5),
#  (399, 32),
#  (400, 40),
#  (401, 78),
#  (402, 271),
#  (403, 265),
#  (404, 29),
#  (405, 45),
#  (406, 147),
#  (407, 32),
#  (408, 115),
#  (409, 297),
#  (410, 96),
#  (411, 168),
#  (412, 457),
#  (413, 99),
#  (414, 57),
#  (415, 271),
#  (416, 62),
#  (417, 22),
#  (418, 51),
#  (419, 29),
#  (420, 56),
#  (421, 20),
#  (422, 9),
#  (423, 64),
#  (424, 341),
#  (425, 189),
#  (426, 239),
#  (427, 27),
#  (428, 50),
#  (429, 346),
#  (430, 63),
#  (431, 84),
#  (432, 73),
#  (433, 46),
#  (434, 43),
#  (435, 132),
#  (436, 133),
#  (437, 52),
#  (438, 411),
#  (439, 65),
#  (440, 29),
#  (441, 47),
#  (442, 51),
#  (443, 34),
#  (444, 120),
#  (445, 286),
#  (446, 51),
#  (447, 37),
#  (448, 23),
#  (449, 54),
#  (450, 51),
#  (451, 209),
#  (452, 132),
#  (453, 367),
#  (454, 147),
#  (455, 25),
#  (456, 157),
#  (457, 237),
#  (458, 43),
#  (459, 32),
#  (460, 47),
#  (461, 512),
#  (462, 120),
#  (463, 123),
#  (464, 82),
#  (465, 37),
#  (466, 199),
#  (467, 69),
#  (468, 26),
#  (469, 49),
#  (470, 68),
#  (471, 105),
#  (472, 45),
#  (473, 49),
#  (474, 318),
#  (475, 247),
#  (476, 431),
#  (477, 211),
#  (478, 46),
#  (479, 93),
#  (480, 88),
#  (481, 198),
#  (482, 745),
#  (483, 29),
#  (484, 34),
#  (485, 45),
#  (486, 39),
#  (487, 24),
#  (488, 25),
#  (489, 24),
#  (490, 77),
#  (491, 25),
#  (492, 32),
#  (493, 158),
#  (494, 191),
#  (495, 44),
#  (496, 46),
#  (497, 24),
#  (498, 172),
#  (499, 199),
#  (500, 87),
#  (501, 67),
#  (502, 24),
#  (503, 29),
#  (504, 108),
#  (505, 115),
#  (506, 90),
#  (507, 9),
#  (508, 149),
#  (509, 723),
#  (510, 99),
#  (511, 27),
#  (512, 37),
#  (513, 156),
#  (514, 63),
#  (515, 162),
#  (516, 294),
#  (517, 166),
#  (518, 7),
#  (519, 36),
#  (520, 302),
#  (521, 41),
#  (522, 58),
#  (523, 100),
#  (524, 1016),
#  (525, 40),
#  (526, 58),
#  (527, 25),
#  (528, 234),
#  (529, 105),
#  (530, 105),
#  (531, 7),
#  (532, 43),
#  (533, 591),
#  (534, 103),
#  (535, 21),
#  (536, 210),
#  (537, 98),
#  (538, 48),
#  (539, 132),
#  (540, 39),
#  (541, 190),
#  (542, 34),
#  (543, 671),
#  (544, 81),
#  (545, 29),
#  (546, 220),
#  (547, 78),
#  (548, 118),
#  (549, 1099),
#  (550, 967),
#  (551, 228),
#  (552, 97),
#  (553, 64),
#  (554, 43),
#  (555, 38),
#  (556, 232),
#  (557, 58),
#  (558, 291),
#  (559, 21),
#  (560, 137),
#  (561, 36),
#  (562, 37),
#  (563, 346),
#  (564, 50),
#  (565, 25),
#  (566, 534),
#  (567, 72),
#  (568, 25),
#  (569, 125),
#  (570, 237),
#  (571, 146),
#  (572, 20),
#  (573, 36),
#  (574, 21),
#  (575, 163),
#  (576, 57),
#  (577, 158),
#  (578, 28),
#  (579, 69),
#  (580, 46),
#  (581, 48),
#  (582, 10),
#  (583, 101),
#  (584, 23),
#  (585, 148),
#  (586, 35),
#  (587, 372),
#  (588, 312),
#  (589, 27),
#  (590, 166),
#  (591, 242),
#  (592, 23),
#  (593, 94),
#  (594, 159),
#  (595, 99),
#  (596, 42),
#  (597, 57),
#  (598, 38),
#  (599, 27),
#  (600, 23),
#  (601, 373),
#  (602, 154),
#  (603, 63),
#  (604, 287),
#  (605, 122),
#  (606, 33),
#  (607, 25),
#  (608, 151),
#  (609, 36),
#  (610, 126),
#  (611, 128),
#  (612, 50),
#  (613, 106),
#  (614, 54),
#  (615, 94),
#  (616, 44),
#  (617, 23),
#  (618, 45),
#  (619, 22),
#  (620, 179),
#  (621, 240),
#  (622, 57),
#  (623, 122),
#  (624, 238),
#  (625, 45),
#  (626, 71),
#  (627, 32),
#  (628, 52),
#  (629, 237),
#  (630, 118),
#  (631, 312),
#  (632, 34),
#  (633, 26),
#  (634, 67),
#  (635, 100),
#  (636, 86),
#  (637, 377),
#  (638, 114),
#  (639, 209),
#  (640, 21),
#  (641, 62),
#  (642, 27),
#  (643, 70),
#  (644, 108),
#  (645, 44),
#  (646, 254),
#  (647, 231),
#  (648, 75),
#  (649, 70),
#  (650, 28),
#  (651, 478),
#  (652, 132),
#  (653, 21),
#  (654, 185),
#  (655, 412),
#  (656, 177),
#  (657, 59),
#  (658, 93),
#  (659, 110),
#  (660, 703),
#  (661, 71),
#  (662, 127),
#  (663, 112),
#  (664, 158),
#  (665, 20),
#  (666, 103),
#  (667, 123),
#  (668, 36),
#  (669, 419),
#  (670, 90),
#  (671, 109),
#  (672, 47),
#  (673, 403),
#  (674, 79),
#  (675, 42),
#  (676, 390),
#  (677, 205),
#  (678, 63),
#  (679, 82),
#  (680, 35),
#  (681, 38),
#  (682, 75),
#  (683, 29),
#  (684, 38),
#  (685, 140),
#  (686, 27),
#  (687, 316),
#  (688, 36),
#  (689, 135),
#  (690, 180),
#  (691, 23),
#  (692, 318),
#  (693, 70),
#  (694, 40),
#  (695, 191),
#  (696, 334),
#  (697, 125),
#  (698, 114),
#  (699, 506),
#  (700, 32),
#  (701, 24),
#  (702, 479),
#  (703, 20),
#  (704, 74),
#  (705, 132),
#  (706, 151),
#  (707, 51),
#  (708, 20),
#  (709, 82),
#  (710, 716),
#  (711, 129),
#  (712, 282),
#  (713, 242),
#  (714, 420),
#  (715, 81),
#  (716, 186),
#  (717, 39),
#  (718, 169),
#  (719, 28),
#  (720, 233),
#  (721, 546),
#  (722, 55),
#  (723, 24),
#  (724, 157),
#  (725, 81),
#  (726, 73),
#  (727, 112),
#  (728, 167),
#  (729, 146),
#  (730, 53),
#  (731, 642),
#  (732, 175),
#  (733, 117),
#  (734, 44),
#  (735, 393),
#  (736, 70),
#  (737, 95),
#  (738, 33),
#  (739, 127),
#  (740, 37),
#  (741, 77),
#  (742, 42),
#  (743, 97),
#  (744, 297),
#  (745, 25),
#  (746, 413),
#  (747, 32),
#  (748, 81),
#  (749, 377),
#  (750, 56),
#  (751, 25),
#  (752, 653),
#  (753, 149),
#  (754, 106),
#  (755, 6),
#  (756, 35),
#  (757, 465),
#  (758, 29),
#  (759, 97),
#  (760, 64),
#  (761, 20),
#  (762, 46),
#  (763, 26),
#  (764, 139),
#  (765, 402),
#  (766, 47),
#  (767, 127),
#  (768, 48),
#  (769, 67),
#  (770, 674),
#  (771, 26),
#  (772, 98),
#  (773, 49),
#  (774, 198),
#  (775, 23),
#  (776, 103),
#  (777, 498),
#  (778, 163),
#  (779, 48),
#  (780, 512),
#  (781, 234),
#  (782, 23),
#  (783, 110),
#  (784, 30),
#  (785, 106),
#  (786, 63),
#  (787, 110),
#  (788, 196),
#  (789, 115),
#  (790, 23),
#  (791, 40),
#  (792, 87),
#  (793, 150),
#  (794, 43),
#  (795, 134),
#  (796, 431),
#  (797, 83),
#  (798, 327),
#  (799, 40),
#  (800, 266),
#  (801, 285),
#  (802, 506),
#  (803, 52),
#  (804, 44),
#  (805, 73),
#  (806, 66),
#  (807, 33),
#  (808, 275),
#  (809, 94),
#  (810, 126),
#  (811, 65),
#  (812, 92),
#  (813, 67),
#  (814, 36),
#  (815, 29),
#  (816, 195),
#  (817, 398),
#  (818, 171),
#  (819, 62),
#  (820, 104),
#  (821, 21),
#  (822, 268),
#  (823, 121),
#  (824, 308),
#  (825, 42),
#  (826, 35),
#  (827, 5),
#  (828, 115),
#  (829, 89),
#  (830, 174),
#  (831, 57),
#  (832, 172),
#  (833, 21),
#  (834, 50),
#  (835, 28),
#  (836, 70),
#  (837, 69),
#  (838, 173),
#  (839, 307),
#  (840, 120),
#  (841, 26),
#  (842, 37),
#  (843, 126),
#  (844, 84),
#  (845, 52),
#  (846, 172),
#  (847, 62),
#  (848, 55),
#  (849, 117),
#  (850, 554),
#  (851, 76),
#  (852, 34),
#  (853, 110),
#  (854, 506),
#  (855, 630),
#  (856, 36),
#  (857, 70),
#  (858, 190),
#  (859, 153),
#  (860, 42),
#  (861, 80),
#  (862, 115),
#  (863, 62),
#  (864, 138),
#  (865, 42),
#  (866, 36),
#  (867, 44),
#  (868, 75),
#  (869, 632),
#  (870, 36),
#  (871, 43),
#  (872, 82),
#  (873, 172),
#  (874, 7),
#  (875, 84),
#  (876, 111),
#  (877, 633),
#  (878, 49),
#  (879, 40),
#  (880, 115),
#  (881, 610),
#  (882, 79),
#  (883, 36),
#  (884, 20),
#  (885, 64),
#  (886, 35),
#  (887, 96),
#  (888, 72),
#  (889, 1518),
#  (890, 107),
#  (891, 223),
#  (892, 34),
#  (893, 110),
#  (894, 70),
#  (895, 64),
#  (896, 64),
#  (897, 165),
#  (898, 24),
#  (899, 316),
#  (900, 26),
#  (901, 33),
#  (902, 25),
#  (903, 74),
#  (904, 205),
#  (905, 123),
#  (906, 21),
#  (907, 21),
#  (908, 39),
#  (909, 71),
#  (910, 131),
#  (911, 433),
#  (912, 43),
#  (913, 31),
#  (914, 61),
#  (915, 95),
#  (916, 55),
#  (917, 29),
#  (918, 144),
#  (919, 326),
#  (920, 78),
#  (921, 158),
#  (922, 343),
#  (923, 46),
#  (924, 199),
#  (925, 68),
#  (926, 60),
#  (927, 108),
#  (928, 212),
#  (929, 337),
#  (930, 54),
#  (931, 157),
#  (932, 20),
#  (933, 62),
#  (934, 139),
#  (935, 388),
#  (936, 88),
#  (937, 57),
#  (938, 31),
#  (939, 165),
#  (940, 130),
#  (941, 28),
#  (942, 25),
#  (943, 69),
#  (944, 45),
#  (945, 163),
#  (946, 33),
#  (947, 20),
#  (948, 512),
#  (949, 369),
#  (950, 55),
#  (951, 21),
#  (952, 157),
#  (953, 148),
#  (954, 126),
#  (955, 338),
#  (956, 108),
#  (957, 323),
#  (958, 158),
#  (959, 14),
#  (960, 128),
#  (961, 50),
#  (962, 50),
#  (963, 366),
#  (964, 78),
#  (965, 77),
#  (966, 165),
#  (967, 91),
#  (968, 61),
#  (969, 26),
#  (970, 434),
#  (971, 223),
#  (972, 35),
#  (973, 217),
#  (974, 60),
#  (975, 404),
#  (976, 55),
#  (977, 240),
#  (978, 44),
#  (979, 13),
#  (980, 135),
#  (981, 210),
#  (982, 51),
#  (983, 78),
#  (984, 687),
#  (985, 146),
#  (986, 22),
#  (987, 169),
#  (988, 73),
#  (989, 44),
#  (990, 102),
#  (991, 60),
#  (992, 31),
#  (993, 15),
#  (994, 39),
#  (995, 49),
#  (996, 275),
#  (997, 29),
#  (998, 135),
#  (999, 412),
#  (1000, 84),
#  (1001, 365),
#  (1002, 66),
#  ...]

# %% [markdown]
# Hago la media de cada peli.

# %%
media_peli = anno_2000.join(num_votos_peli).map(lambda x:(x[0],(x[1][0]/x[1][1]))).sortByKey()

# %%
media_peli.collect()
# Out:
# [(1, 4.175),
#  (2, 3.7131782945736433),
#  (3, 3.9019607843137254),
#  (4, 4.190476190476191),
#  (5, 3.1464646464646466),
#  (6, 3.9014084507042255),
#  (7, 4.32258064516129),
#  (8, 3.884892086330935),
#  (9, 3.7358490566037736),
#  (10, 4.066889632107023),
#  (11, 3.7818181818181817),
#  (12, 3.8260869565217392),
#  (13, 3.388888888888889),
#  (14, 3.32),
#  (15, 3.315),
#  (16, 3.0285714285714285),
#  (17, 4.075829383886256),
#  (18, 3.6491803278688524),
#  (19, 3.7628865979381443),
#  (20, 4.384615384615385),
#  (21, 2.909090909090909),
#  (22, 3.0364372469635628),
#  (23, 3.0),
#  (24, 3.9389312977099236),
#  (25, 3.8157894736842106),
#  (26, 2.954659949622166),
#  (27, 4.171428571428572),
#  (28, 3.8241758241758244),
#  (29, 3.5833333333333335),
#  (30, 3.488372093023256),
#  (31, 3.73109243697479),
#  (32, 3.625),
#  (33, 3.61734693877551),
#  (34, 3.8658536585365852),
#  (35, 3.54040404040404),
#  (36, 4.20216606498195),
#  (37, 3.69811320754717),
#  (38, 3.58),
#  (39, 3.564516129032258),
#  (40, 3.4479166666666665),
#  (41, 3.48),
#  (42, 3.74025974025974),
#  (43, 4.125),
#  (44, 3.9145299145299144),
#  (45, 2.946127946127946),
#  (46, 4.219512195121951),
#  (47, 3.909090909090909),
#  (48, 3.0686767169179228),
#  (49, 3.6804123711340204),
#  (50, 3.0697674418604652),
#  (51, 3.825),
#  (52, 3.5569620253164556),
#  (53, 4.2368421052631575),
#  (54, 4.025),
#  (55, 4.12),
#  (56, 3.970149253731343),
#  (57, 2.90625),
#  (58, 3.9725400457665905),
#  (59, 3.5376344086021505),
#  (60, 3.414285714285714),
#  (61, 2.7777777777777777),
#  (62, 3.566265060240964),
#  (63, 3.2976190476190474),
#  (64, 4.148148148148148),
#  (65, 4.527777777777778),
#  (66, 3.8461538461538463),
#  (67, 4.296875),
#  (68, 3.6904761904761907),
#  (69, 4.153846153846154),
#  (70, 3.7037037037037037),
#  (71, 3.7586206896551726),
#  (72, 3.697674418604651),
#  (73, 3.376237623762376),
#  (74, 4.0),
#  (75, 3.9659863945578233),
#  (76, 4.4375),
#  (77, 2.948717948717949),
#  (78, 3.659090909090909),
#  (79, 3.6451612903225805),
#  (80, 3.872340425531915),
#  (81, 4.4186046511627906),
#  (82, 4.035398230088496),
#  (83, 3.5757575757575757),
#  (84, 3.838709677419355),
#  (85, 3.0),
#  (86, 4.068965517241379),
#  (87, 2.8135593220338984),
#  (88, 4.147058823529412),
#  (89, 3.9),
#  (90, 3.888888888888889),
#  (91, 4.704545454545454),
#  (92, 3.0816326530612246),
#  (93, 2.9727272727272727),
#  (94, 3.857142857142857),
#  (95, 3.595959595959596),
#  (96, 2.8),
#  (97, 4.473684210526316),
#  (98, 3.8),
#  (99, 3.4285714285714284),
#  (100, 3.026315789473684),
#  (101, 4.679245283018868),
#  (102, 4.5),
#  (103, 4.052173913043478),
#  (104, 3.6333333333333333),
#  (105, 4.295081967213115),
#  (106, 4.0212765957446805),
#  (107, 3.743801652892562),
#  (108, 3.135135135135135),
#  (109, 4.0),
#  (110, 3.25),
#  (111, 3.7282608695652173),
#  (112, 4.183333333333334),
#  (113, 3.5),
#  (114, 3.5764705882352943),
#  (115, 3.8421052631578947),
#  (116, 3.75),
#  (117, 3.2996031746031744),
#  (118, 3.767857142857143),
#  (119, 3.5428571428571427),
#  (120, 3.619047619047619),
#  (121, 4.416666666666667),
#  (122, 3.3095238095238093),
#  (123, 3.418918918918919),
#  (124, 4.0),
#  (125, 4.098591549295775),
#  (126, 4.0),
#  (127, 4.052083333333333),
#  (128, 4.363636363636363),
#  (129, 4.025316455696203),
#  (130, 4.311111111111111),
#  (131, 3.4306569343065694),
#  (132, 3.966292134831461),
#  (133, 3.7804878048780486),
#  (134, 2.682926829268293),
#  (135, 3.657142857142857),
#  (136, 3.074074074074074),
#  (137, 3.4727272727272727),
#  (138, 4.492307692307692),
#  (139, 3.8816326530612244),
#  (140, 3.4),
#  (141, 3.6956521739130435),
#  (142, 3.2162162162162162),
#  (143, 3.5441176470588234),
#  (144, 3.46875),
#  (145, 3.0),
#  (146, 3.75),
#  (147, 3.5026737967914436),
#  (148, 3.624),
#  (149, 4.035545023696683),
#  (150, 4.009174311926605),
#  (151, 3.6219512195121952),
#  (152, 4.125),
#  (153, 4.133333333333334),
#  (154, 3.090909090909091),
#  (155, 2.96875),
#  (156, 4.236486486486487),
#  (157, 3.677581863979849),
#  (158, 4.0),
#  (160, 3.4285714285714284),
#  (161, 4.4713804713804715),
#  (162, 4.093023255813954),
#  (163, 2.1828793774319064),
#  (164, 4.142857142857143),
#  (165, 3.981818181818182),
#  (166, 3.6707920792079207),
#  (167, 2.9310344827586206),
#  (168, 3.8461538461538463),
#  (169, 3.6505050505050507),
#  (170, 3.9885057471264367),
#  (171, 4.0),
#  (172, 3.608695652173913),
#  (173, 3.909090909090909),
#  (174, 3.649484536082474),
#  (175, 3.9904458598726116),
#  (176, 3.6153846153846154),
#  (177, 4.113636363636363),
#  (178, 3.8434782608695652),
#  (179, 2.6545454545454548),
#  (180, 3.9047619047619047),
#  (181, 3.604651162790698),
#  (182, 3.8313253012048194),
#  (183, 4.086956521739131),
#  (184, 3.857142857142857),
#  (185, 3.588235294117647),
#  (186, 4.254098360655738),
#  (187, 4.083932853717027),
#  (188, 2.6),
#  (189, 4.0),
#  (190, 3.6993464052287583),
#  (191, 3.3333333333333335),
#  (192, 3.0492813141683777),
#  (193, 3.82),
#  (194, 3.983050847457627),
#  (195, 4.260869565217392),
#  (196, 4.0625),
#  (197, 3.909090909090909),
#  (198, 3.755434782608696),
#  (199, 3.2761194029850746),
#  (200, 3.423076923076923),
#  (201, 4.014925373134329),
#  (202, 3.2492537313432837),
#  (203, 2.2913385826771653),
#  (204, 3.4412698412698415),
#  (205, 4.0588235294117645),
#  (206, 3.066666666666667),
#  (207, 3.5217391304347827),
#  (208, 3.757575757575758),
#  (209, 3.16),
#  (210, 4.027272727272727),
#  (211, 3.857142857142857),
#  (212, 3.8545454545454545),
#  (213, 4.2272727272727275),
#  (214, 3.1626506024096384),
#  (215, 4.5625),
#  (216, 3.2317380352644838),
#  (217, 3.7),
#  (218, 3.0259740259740258),
#  (219, 3.3333333333333335),
#  (220, 4.215686274509804),
#  (221, 3.2413793103448274),
#  (222, 4.0875),
#  (223, 3.44140625),
#  (224, 3.5142857142857142),
#  (225, 3.4330708661417324),
#  (226, 3.5714285714285716),
#  (227, 3.2857142857142856),
#  (228, 3.9583333333333335),
#  (229, 3.4096385542168677),
#  (230, 4.094972067039106),
#  (231, 4.636363636363637),
#  (232, 3.566666666666667),
#  (233, 4.584905660377358),
#  (234, 4.217391304347826),
#  (235, 4.142045454545454),
#  (236, 3.693548387096774),
#  (237, 3.8607594936708862),
#  (238, 3.7868217054263567),
#  (239, 3.7037037037037037),
#  (240, 3.300699300699301),
#  (241, 3.9649122807017543),
#  (242, 3.203846153846154),
#  (243, 3.606060606060606),
#  (244, 4.105882352941176),
#  (245, 2.6714659685863875),
#  (246, 4.0),
#  (247, 3.935483870967742),
#  (248, 4.206896551724138),
#  (249, 3.9454545454545453),
#  (250, 3.75),
#  (251, 3.5753424657534247),
#  (252, 4.016666666666667),
#  (253, 3.9245283018867925),
#  (254, 3.782608695652174),
#  (255, 4.016393442622951),
#  (256, 3.8526315789473684),
#  (257, 4.452830188679245),
#  (258, 3.717241379310345),
#  (259, 4.021739130434782),
#  (260, 3.311688311688312),
#  (261, 3.5762711864406778),
#  (262, 3.330188679245283),
#  (263, 3.6630434782608696),
#  (264, 2.7471783295711063),
#  (265, 4.1938775510204085),
#  (266, 4.52),
#  (267, 3.3675213675213675),
#  (268, 3.3946360153256707),
#  (269, 3.8),
#  (270, 4.252173913043478),
#  (271, 4.279503105590062),
#  (272, 3.6535269709543567),
#  (273, 3.727272727272727),
#  (274, 4.243243243243243),
#  (275, 4.247191011235955),
#  (276, 3.5217391304347827),
#  (277, 3.727272727272727),
#  (278, 3.9646464646464645),
#  (279, 3.5),
#  (280, 3.94),
#  (281, 3.891891891891892),
#  (282, 3.5172413793103448),
#  (283, 4.962962962962963),
#  (284, 3.021231422505308),
#  (285, 4.159663865546219),
#  (286, 3.883720930232558),
#  (287, 3.70873786407767),
#  (288, 4.589285714285714),
#  (289, 3.9054054054054053),
#  (290, 3.303030303030303),
#  (291, 4.137254901960785),
#  (292, 3.7560975609756095),
#  (293, 3.38659793814433),
#  (294, 3.489795918367347),
#  (295, 3.764397905759162),
#  (296, 3.597938144329897),
#  (297, 4.0),
#  (298, 3.925925925925926),
#  (299, 4.064935064935065),
#  (300, 4.180722891566265),
#  (301, 3.8011204481792715),
#  (302, 2.8604992657856094),
#  (303, 3.8701923076923075),
#  (304, 3.5555555555555554),
#  (305, 2.5605095541401273),
#  (306, 3.96875),
#  (307, 4.593406593406593),
#  (308, 3.5547169811320756),
#  (309, 4.040650406504065),
#  (310, 3.4),
#  (311, 4.125),
#  (312, 3.736842105263158),
#  (313, 4.038461538461538),
#  (314, 3.696),
#  (315, 3.8636363636363638),
#  (316, 4.116883116883117),
#  (317, 3.8095238095238093),
#  (318, 3.9523809523809526),
#  (319, 3.1915285451197053),
#  (320, 4.238095238095238),
#  (321, 3.26027397260274),
#  (322, 4.45),
#  (323, 3.788135593220339),
#  (324, 3.3289473684210527),
#  (325, 4.046511627906977),
#  (326, 3.2987012987012987),
#  (327, 3.669491525423729),
#  (328, 3.032258064516129),
#  (329, 2.7335766423357666),
#  (330, 4.169491525423729),
#  (331, 4.0),
#  (332, 4.277777777777778),
#  (333, 3.4285714285714284),
#  (334, 3.9508196721311477),
#  (335, 2.5),
#  (336, 4.308411214953271),
#  (337, 3.525252525252525),
#  (338, 3.6954314720812182),
#  (339, 4.024193548387097),
#  (340, 3.5277777777777777),
#  (341, 4.2),
#  (342, 3.6910569105691056),
#  (343, 3.8260869565217392),
#  (344, 2.9555555555555557),
#  (345, 4.4),
#  (346, 4.307420494699647),
#  (347, 3.878787878787879),
#  (348, 3.78),
#  (350, 3.9375),
#  (351, 3.757575757575758),
#  (352, 3.4793103448275864),
#  (353, 3.9166666666666665),
#  (354, 3.586206896551724),
#  (355, 3.3776223776223775),
#  (356, 4.266666666666667),
#  (357, 3.293103448275862),
#  (358, 3.8472222222222223),
#  (359, 3.857142857142857),
#  (360, 3.6417910447761193),
#  (361, 3.5384615384615383),
#  (362, 3.3461538461538463),
#  (363, 3.744186046511628),
#  (364, 3.142857142857143),
#  (365, 3.3404255319148937),
#  (366, 4.184210526315789),
#  (367, 4.25),
#  (368, 3.8038461538461537),
#  (369, 3.1954022988505746),
#  (370, 3.75),
#  (371, 3.5),
#  (372, 4.382978723404255),
#  (373, 3.5555555555555554),
#  (374, 4.403846153846154),
#  (375, 3.5714285714285716),
#  (376, 4.75),
#  (377, 3.9044117647058822),
#  (378, 3.5128205128205128),
#  (379, 4.234375),
#  (380, 3.7246376811594204),
#  (381, 4.114285714285714),
#  (382, 4.055555555555555),
#  (383, 3.5714285714285716),
#  (384, 3.590909090909091),
#  (385, 3.9562043795620436),
#  (386, 3.3230769230769233),
#  (387, 3.640625),
#  (388, 3.8813559322033897),
#  (389, 3.5616438356164384),
#  (390, 3.6728971962616823),
#  (391, 3.689189189189189),
#  (392, 3.4642857142857144),
#  (393, 3.581081081081081),
#  (394, 3.3421052631578947),
#  (395, 3.608695652173913),
#  (396, 3.560693641618497),
#  (397, 3.8823529411764706),
#  (398, 2.8),
#  (399, 4.15625),
#  (400, 3.875),
#  (401, 3.871794871794872),
#  (402, 3.6199261992619927),
#  (403, 3.8264150943396227),
#  (404, 4.275862068965517),
#  (405, 3.7555555555555555),
#  (406, 3.306122448979592),
#  (407, 3.4375),
#  (408, 4.643478260869565),
#  (409, 3.9158249158249157),
#  (410, 3.96875),
#  (411, 3.488095238095238),
#  (412, 4.420131291028446),
#  (413, 4.404040404040404),
#  (414, 3.0701754385964914),
#  (415, 3.874538745387454),
#  (416, 3.7580645161290325),
#  (417, 4.045454545454546),
#  (418, 3.549019607843137),
#  (419, 3.9655172413793105),
#  (420, 4.375),
#  (421, 4.25),
#  (422, 3.6666666666666665),
#  (423, 2.5),
#  (424, 4.126099706744868),
#  (425, 3.6613756613756614),
#  (426, 3.7573221757322175),
#  (427, 4.111111111111111),
#  (428, 3.9),
#  (429, 3.346820809248555),
#  (430, 3.9682539682539684),
#  (431, 3.630952380952381),
#  (432, 2.9863013698630136),
#  (433, 3.391304347826087),
#  (434, 4.023255813953488),
#  (435, 3.8333333333333335),
#  (436, 3.8345864661654137),
#  (437, 4.3076923076923075),
#  (438, 3.5839416058394162),
#  (439, 3.9692307692307693),
#  (440, 3.586206896551724),
#  (441, 3.9574468085106385),
#  (442, 4.431372549019608),
#  (443, 3.823529411764706),
#  (444, 4.0),
#  (445, 3.3181818181818183),
#  (446, 4.8431372549019605),
#  (447, 4.837837837837838),
#  (448, 3.4347826086956523),
#  (449, 3.7222222222222223),
#  (450, 4.196078431372549),
#  (451, 4.511961722488039),
#  (452, 4.431818181818182),
#  (453, 3.629427792915531),
#  (454, 3.741496598639456),
#  (455, 4.2),
#  (456, 3.394904458598726),
#  (457, 3.7130801687763713),
#  (458, 3.5348837209302326),
#  (459, 3.6875),
#  (460, 3.3617021276595747),
#  (461, 3.224609375),
#  (462, 3.591666666666667),
#  (463, 3.0),
#  (464, 3.6097560975609757),
#  (465, 3.5405405405405403),
#  (466, 4.14070351758794),
#  (467, 3.2028985507246377),
#  (468, 3.730769230769231),
#  (469, 4.326530612244898),
#  (470, 3.8088235294117645),
#  (471, 3.6285714285714286),
#  (472, 4.022222222222222),
#  (473, 4.163265306122449),
#  (474, 3.380503144654088),
#  (475, 3.8299595141700404),
#  (476, 3.8375870069605567),
#  (477, 3.5829383886255926),
#  (478, 3.869565217391304),
#  (479, 3.827956989247312),
#  (480, 3.534090909090909),
#  (481, 3.696969696969697),
#  (482, 3.293959731543624),
#  (483, 2.9310344827586206),
#  (484, 3.735294117647059),
#  (485, 4.044444444444444),
#  (486, 4.051282051282051),
#  (487, 3.5),
#  (488, 3.56),
#  (489, 3.3333333333333335),
#  (490, 3.7662337662337664),
#  (491, 3.68),
#  (492, 3.9375),
#  (493, 3.848101265822785),
#  (494, 4.157068062827225),
#  (495, 3.7954545454545454),
#  (496, 4.391304347826087),
#  (497, 3.5833333333333335),
#  (498, 3.6511627906976742),
#  (499, 3.9748743718592965),
#  (500, 3.586206896551724),
#  (501, 3.417910447761194),
#  (502, 4.083333333333333),
#  (503, 4.448275862068965),
#  (504, 3.8055555555555554),
#  (505, 4.217391304347826),
#  (506, 3.422222222222222),
#  (507, 3.7777777777777777),
#  (508, 3.3221476510067114),
#  (509, 3.3139695712309822),
#  (510, 3.8282828282828283),
#  (511, 3.740740740740741),
#  (512, 3.8378378378378377),
#  (513, 3.1474358974358974),
#  (514, 4.190476190476191),
#  (515, 3.728395061728395),
#  (516, 2.931972789115646),
#  (517, 3.963855421686747),
#  (518, 3.857142857142857),
#  (519, 3.3333333333333335),
#  (520, 3.943708609271523),
#  (521, 4.2926829268292686),
#  (522, 3.8448275862068964),
#  (523, 4.06),
#  (524, 3.608267716535433),
#  (525, 4.025),
#  (526, 3.896551724137931),
#  (527, 4.08),
#  (528, 3.675213675213675),
#  (529, 4.190476190476191),
#  (530, 4.0),
#  (531, 3.142857142857143),
#  (532, 3.86046511627907),
#  (533, 3.3401015228426396),
#  (534, 3.7475728155339807),
#  (535, 3.5714285714285716),
#  (536, 3.942857142857143),
#  (537, 4.3061224489795915),
#  (538, 4.458333333333333),
#  (539, 3.9242424242424243),
#  (540, 3.230769230769231),
#  (541, 3.1894736842105265),
#  (542, 3.764705882352941),
#  (543, 4.078986587183309),
#  (544, 3.7777777777777777),
#  (545, 3.4827586206896552),
#  (546, 3.231818181818182),
#  (547, 3.858974358974359),
#  (548, 3.093220338983051),
#  (549, 3.8061874431301184),
#  (550, 3.578076525336091),
#  (551, 3.8201754385964914),
#  (552, 3.7628865979381443),
#  (553, 4.15625),
#  (554, 3.511627906976744),
#  (555, 3.8157894736842106),
#  (556, 3.5),
#  (557, 3.8793103448275863),
#  (558, 3.6804123711340204),
#  (559, 3.0),
#  (560, 3.897810218978102),
#  (561, 3.7222222222222223),
#  (562, 3.7027027027027026),
#  (563, 2.7023121387283235),
#  (564, 4.0),
#  (565, 3.44),
#  (566, 2.6273408239700373),
#  (567, 4.583333333333333),
#  (568, 4.44),
#  (569, 3.52),
#  (570, 3.329113924050633),
#  (571, 3.7054794520547945),
#  (572, 3.05),
#  (573, 3.9722222222222223),
#  (574, 4.095238095238095),
#  (575, 3.6564417177914113),
#  (576, 3.6666666666666665),
#  (577, 4.487341772151899),
#  (578, 3.9642857142857144),
#  (579, 3.8550724637681157),
#  (580, 3.347826086956522),
#  (581, 3.6666666666666665),
#  (582, 4.7),
#  (583, 4.118811881188119),
#  (584, 4.173913043478261),
#  (585, 3.4662162162162162),
#  (586, 4.485714285714286),
#  (587, 3.013440860215054),
#  (588, 4.083333333333333),
#  (589, 4.0),
#  (590, 4.13855421686747),
#  (591, 3.231404958677686),
#  (592, 4.391304347826087),
#  (593, 3.6702127659574466),
#  (594, 4.29559748427673),
#  (595, 3.9494949494949494),
#  (596, 2.9523809523809526),
#  (597, 4.473684210526316),
#  (598, 3.3157894736842106),
#  (599, 3.8518518518518516),
#  (600, 3.652173913043478),
#  (601, 3.1501340482573728),
#  (602, 3.396103896103896),
#  (603, 3.5238095238095237),
#  (604, 3.0940766550522647),
#  (605, 4.049180327868853),
#  (606, 4.03030303030303),
#  (607, 4.16),
#  (608, 3.198675496688742),
#  (609, 4.25),
#  (610, 3.484126984126984),
#  (611, 3.953125),
#  (612, 3.5),
#  (613, 3.5849056603773586),
#  (614, 3.8333333333333335),
#  (615, 4.127659574468085),
#  (616, 3.9545454545454546),
#  (617, 4.086956521739131),
#  (618, 3.0),
#  (619, 3.909090909090909),
#  (620, 3.3240223463687153),
#  (621, 3.0416666666666665),
#  (622, 3.912280701754386),
#  (623, 4.155737704918033),
#  (624, 3.638655462184874),
#  (625, 4.0),
#  (626, 4.042253521126761),
#  (627, 3.5625),
#  (628, 3.9038461538461537),
#  (629, 3.371308016877637),
#  (630, 4.254237288135593),
#  (631, 3.7948717948717947),
#  (632, 3.7941176470588234),
#  (633, 3.6538461538461537),
#  (634, 4.014925373134329),
#  (635, 4.39),
#  (636, 4.058139534883721),
#  (637, 3.7559681697612732),
#  (638, 4.175438596491228),
#  (639, 3.665071770334928),
#  (640, 4.333333333333333),
#  (641, 3.8870967741935485),
#  (642, 4.111111111111111),
#  (643, 2.7142857142857144),
#  (644, 3.1203703703703702),
#  (645, 4.4772727272727275),
#  (646, 3.8031496062992125),
#  (647, 3.103896103896104),
#  (648, 3.8266666666666667),
#  (649, 3.6714285714285713),
#  (650, 3.9642857142857144),
#  (651, 3.6129707112970713),
#  (652, 2.8863636363636362),
#  (653, 4.142857142857143),
#  (654, 3.4324324324324325),
#  (655, 2.733009708737864),
#  (656, 3.8700564971751414),
#  (657, 4.016949152542373),
#  (658, 3.096774193548387),
#  (659, 3.7),
#  (660, 3.0170697012802274),
#  (661, 4.647887323943662),
#  (662, 3.141732283464567),
#  (663, 3.580357142857143),
#  (664, 4.025316455696203),
#  (665, 3.5),
#  (666, 3.8932038834951457),
#  (667, 3.016260162601626),
#  (668, 3.5833333333333335),
#  (669, 3.847255369928401),
#  (670, 3.2444444444444445),
#  (671, 4.256880733944954),
#  (672, 3.872340425531915),
#  (673, 3.13151364764268),
#  (674, 4.2784810126582276),
#  (675, 3.3095238095238093),
#  (676, 3.128205128205128),
#  (677, 3.892682926829268),
#  (678, 4.015873015873016),
#  (679, 3.926829268292683),
#  (680, 3.5714285714285716),
#  (681, 4.2368421052631575),
#  (682, 4.733333333333333),
#  (683, 3.586206896551724),
#  (684, 3.8947368421052633),
#  (685, 3.2357142857142858),
#  (686, 3.7777777777777777),
#  (687, 3.4873417721518987),
#  (688, 3.75),
#  (689, 3.3925925925925924),
#  (690, 4.311111111111111),
#  (691, 4.260869565217392),
#  (692, 3.889937106918239),
#  (693, 3.8857142857142857),
#  (694, 3.625),
#  (695, 3.513089005235602),
#  (696, 3.817365269461078),
#  (697, 3.8),
#  (698, 3.789473684210526),
#  (699, 3.025691699604743),
#  (700, 3.875),
#  (701, 3.8333333333333335),
#  (702, 3.3027139874739038),
#  (703, 4.1),
#  (704, 3.081081081081081),
#  (705, 3.371212121212121),
#  (706, 3.556291390728477),
#  (707, 3.627450980392157),
#  (708, 3.85),
#  (709, 2.8292682926829267),
#  (710, 3.4818435754189943),
#  (711, 3.9767441860465116),
#  (712, 3.475177304964539),
#  (713, 3.446280991735537),
#  (714, 4.171428571428572),
#  (715, 3.9012345679012346),
#  (716, 4.403225806451613),
#  (717, 3.1538461538461537),
#  (718, 3.775147928994083),
#  (719, 3.5),
#  (720, 2.9098712446351933),
#  (721, 3.5567765567765566),
#  (722, 3.909090909090909),
#  (723, 3.8333333333333335),
#  (724, 3.643312101910828),
#  (725, 4.197530864197531),
#  (726, 3.9315068493150687),
#  (727, 3.5535714285714284),
#  (728, 3.311377245508982),
#  (729, 3.5273972602739727),
#  (730, 3.7735849056603774),
#  (731, 3.778816199376947),
#  (732, 3.4285714285714284),
#  (733, 4.05982905982906),
#  (734, 3.727272727272727),
#  (735, 3.590330788804071),
#  (736, 3.842857142857143),
#  (737, 3.694736842105263),
#  (738, 3.303030303030303),
#  (739, 4.354330708661418),
#  (740, 4.243243243243243),
#  (741, 3.324675324675325),
#  (742, 3.9523809523809526),
#  (743, 3.381443298969072),
#  (744, 3.3703703703703702),
#  (745, 2.64),
#  (746, 2.6198547215496366),
#  (747, 3.59375),
#  (748, 3.9753086419753085),
#  (749, 3.3660477453580904),
#  (750, 4.321428571428571),
#  (751, 3.88),
#  (752, 2.909647779479326),
#  (753, 3.6778523489932886),
#  (754, 3.9150943396226414),
#  (755, 4.333333333333333),
#  (756, 3.9714285714285715),
#  (757, 3.225806451612903),
#  (758, 4.0),
#  (759, 3.5876288659793816),
#  (760, 4.265625),
#  (761, 4.55),
#  (762, 3.717391304347826),
#  (763, 3.730769230769231),
#  (764, 4.525179856115108),
#  (765, 3.574626865671642),
#  (766, 3.9361702127659575),
#  (767, 4.05511811023622),
#  (768, 4.4375),
#  (769, 3.8208955223880596),
#  (770, 2.8827893175074184),
#  (771, 3.769230769230769),
#  (772, 3.479591836734694),
#  (773, 3.5918367346938775),
#  (774, 3.217171717171717),
#  (775, 4.0),
#  (776, 3.766990291262136),
#  (777, 2.57429718875502),
#  (778, 3.785276073619632),
#  (779, 3.3333333333333335),
#  (780, 3.45703125),
#  (781, 3.1709401709401708),
#  (782, 3.4347826086956523),
#  (783, 3.581818181818182),
#  (784, 4.066666666666666),
#  (785, 3.2358490566037736),
#  (786, 4.063492063492063),
#  (787, 3.590909090909091),
#  (788, 3.5255102040816326),
#  (789, 2.9043478260869566),
#  (790, 4.3478260869565215),
#  (791, 3.725),
#  (792, 3.4597701149425286),
#  (793, 3.486666666666667),
#  (794, 3.953488372093023),
#  (795, 3.470149253731343),
#  (796, 2.988399071925754),
#  (797, 4.036144578313253),
#  (798, 3.149847094801223),
#  (799, 3.6),
#  (800, 3.4849624060150375),
#  (801, 3.6596491228070174),
#  (802, 3.938735177865613),
#  (803, 3.7115384615384617),
#  (804, 3.272727272727273),
#  (805, 3.835616438356164),
#  (806, 4.166666666666667),
#  (807, 3.9696969696969697),
#  (808, 3.1236363636363635),
#  (809, 4.031914893617022),
#  (810, 3.8174603174603177),
#  (811, 4.184615384615385),
#  (812, 3.739130434782609),
#  (813, 3.343283582089552),
#  (814, 4.055555555555555),
#  (815, 4.068965517241379),
#  (816, 3.6974358974358976),
#  (817, 4.010050251256281),
#  (818, 3.7251461988304095),
#  (819, 3.3225806451612905),
#  (820, 3.4134615384615383),
#  (821, 2.9523809523809526),
#  (822, 3.712686567164179),
#  (823, 3.8677685950413223),
#  (824, 3.646103896103896),
#  (825, 3.619047619047619),
#  (826, 3.2857142857142856),
#  (827, 3.4),
#  (828, 3.4434782608695653),
#  (829, 4.359550561797753),
#  (830, 3.6149425287356323),
#  (831, 4.105263157894737),
#  (832, 3.558139534883721),
#  (833, 4.0476190476190474),
#  (834, 4.16),
#  (835, 2.75),
#  (836, 2.4),
#  (837, 3.260869565217391),
#  (838, 4.08092485549133),
#  (839, 4.247557003257329),
#  (840, 4.341666666666667),
#  (841, 3.576923076923077),
#  (842, 3.8378378378378377),
#  (843, 3.9444444444444446),
#  (844, 3.4523809523809526),
#  (845, 3.980769230769231),
#  (846, 3.936046511627907),
#  (847, 3.6129032258064515),
#  (848, 4.181818181818182),
#  (849, 3.264957264957265),
#  (850, 3.5613718411552346),
#  (851, 3.5921052631578947),
#  (852, 4.117647058823529),
#  (853, 3.890909090909091),
#  (854, 3.027667984189723),
#  (855, 3.4126984126984126),
#  (856, 3.638888888888889),
#  (857, 4.171428571428572),
#  (858, 4.189473684210526),
#  (859, 3.450980392156863),
#  (860, 3.1666666666666665),
#  (861, 3.9375),
#  (862, 3.6695652173913045),
#  (863, 4.225806451612903),
#  (864, 4.050724637681159),
#  (865, 3.8095238095238093),
#  (866, 3.3333333333333335),
#  (867, 3.659090909090909),
#  (868, 3.6),
#  (869, 3.550632911392405),
#  (870, 3.611111111111111),
#  (871, 3.9069767441860463),
#  (872, 3.6463414634146343),
#  (873, 3.8430232558139537),
#  (874, 3.142857142857143),
#  (875, 4.083333333333333),
#  (876, 3.828828828828829),
#  (877, 3.308056872037915),
#  (878, 4.142857142857143),
#  (879, 4.025),
#  (880, 3.4956521739130433),
#  (881, 2.7491803278688525),
#  (882, 4.0886075949367084),
#  (883, 3.4166666666666665),
#  (884, 4.15),
#  (885, 4.140625),
#  (886, 3.6285714285714286),
#  (887, 3.5104166666666665),
#  (888, 3.7777777777777777),
#  (889, 2.8405797101449277),
#  (890, 3.635514018691589),
#  (891, 3.7443946188340806),
#  (892, 3.911764705882353),
#  (893, 3.2),
#  (894, 4.442857142857143),
#  (895, 3.953125),
#  (896, 3.984375),
#  (897, 3.503030303030303),
#  (898, 4.083333333333333),
#  (899, 3.528481012658228),
#  (900, 3.576923076923077),
#  (901, 3.606060606060606),
#  (902, 4.28),
#  (903, 3.4594594594594597),
#  (904, 3.317073170731707),
#  (905, 3.7886178861788617),
#  (906, 3.5238095238095237),
#  (907, 3.9523809523809526),
#  (908, 3.3076923076923075),
#  (909, 3.9014084507042255),
#  (910, 3.5572519083969465),
#  (911, 3.884526558891455),
#  (912, 3.7209302325581395),
#  (913, 3.3870967741935485),
#  (914, 4.278688524590164),
#  (915, 2.831578947368421),
#  (916, 3.9454545454545453),
#  (917, 4.068965517241379),
#  (918, 2.9583333333333335),
#  (919, 3.9355828220858897),
#  (920, 3.4615384615384617),
#  (921, 3.6962025316455698),
#  (922, 3.5830903790087465),
#  (923, 3.608695652173913),
#  (924, 3.9899497487437188),
#  (925, 3.1323529411764706),
#  (926, 4.333333333333333),
#  (927, 3.2777777777777777),
#  (928, 4.3254716981132075),
#  (929, 3.7685459940652817),
#  (930, 3.2222222222222223),
#  (931, 4.031847133757962),
#  (932, 4.45),
#  (933, 3.7096774193548385),
#  (934, 2.985611510791367),
#  (935, 3.4896907216494846),
#  (936, 3.5113636363636362),
#  (937, 3.789473684210526),
#  (938, 3.870967741935484),
#  (939, 3.757575757575758),
#  (940, 3.1923076923076925),
#  (941, 2.2857142857142856),
#  (942, 4.04),
#  (943, 4.333333333333333),
#  (944, 3.8444444444444446),
#  (945, 3.6196319018404908),
#  (946, 4.303030303030303),
#  (947, 3.0),
#  (948, 3.7421875),
#  (949, 3.9295392953929538),
#  (950, 2.963636363636364),
#  (951, 4.523809523809524),
#  (952, 3.9936305732484074),
#  (953, 4.6824324324324325),
#  (954, 3.7777777777777777),
#  (955, 3.5798816568047336),
#  (956, 3.990740740740741),
#  (957, 4.272445820433436),
#  (958, 3.9050632911392404),
#  (959, 3.7857142857142856),
#  (960, 3.9375),
#  (961, 3.74),
#  (962, 4.08),
#  (963, 3.3934426229508197),
#  (964, 3.717948717948718),
#  (965, 4.116883116883117),
#  (966, 3.5636363636363635),
#  (967, 3.5384615384615383),
#  (968, 4.131147540983607),
#  (969, 4.115384615384615),
#  (970, 3.2350230414746544),
#  (971, 3.3318385650224216),
#  (972, 3.3714285714285714),
#  (973, 3.3963133640552994),
#  (974, 3.7333333333333334),
#  (975, 3.25990099009901),
#  (976, 3.3636363636363638),
#  (977, 3.7625),
#  (978, 3.8863636363636362),
#  (979, 3.6923076923076925),
#  (980, 3.2222222222222223),
#  (981, 3.342857142857143),
#  (982, 4.176470588235294),
#  (983, 4.115384615384615),
#  (984, 3.542940320232897),
#  (985, 4.212328767123288),
#  (986, 3.772727272727273),
#  (987, 4.035502958579881),
#  (988, 3.8493150684931505),
#  (989, 4.681818181818182),
#  (990, 3.549019607843137),
#  (991, 3.75),
#  (992, 3.4193548387096775),
#  (993, 3.1333333333333333),
#  (994, 4.153846153846154),
#  (995, 3.8979591836734695),
#  (996, 3.938181818181818),
#  (997, 3.9310344827586206),
#  (998, 4.118518518518519),
#  (999, 3.186893203883495),
#  (1000, 4.130952380952381),
#  (1001, 3.673972602739726),
#  (1002, 4.136363636363637),
#  ...]

# %%
anno_2000.count(), media_peli.count()
# Out:
# (6034, 6034)

# %% [markdown]
# Saco la media del año 2000.

# %%
media_2000 = media_peli.map(lambda x: x[1]).mean()

# %%
media_2000
# Out:
# 3.7084709202666426

# %% [markdown]
# __REPITO EL PROCESO PARA EL RESTO DE AÑOS__

# %% [markdown]
# #### Año 2001

# %%
anno_2001 = ratings_splitted.filter(lambda x: x[3] == 2001).map(lambda x: (x[0],x[2])).reduceByKey(lambda a,b:a + b)
num_votos_peli2001 = ratings_splitted.filter(lambda x: x[3] == 2001).map(lambda x: (x[0],1)).reduceByKey(lambda a,b:a + b)
media_peli2001 = anno_2001.join(num_votos_peli2001).map(lambda x:(x[0],(x[1][0]/x[1][1]))).sortByKey()
media_2001 = media_peli2001.map(lambda x: x[1]).mean()
media_2001
# Out:
# 3.6379066147771963

# %% [markdown]
# #### Año 2002

# %%
anno_2002 = ratings_splitted.filter(lambda x: x[3] == 2002).map(lambda x: (x[0],x[2])).reduceByKey(lambda a,b:a + b)
num_votos_peli2002 = ratings_splitted.filter(lambda x: x[3] == 2002).map(lambda x: (x[0],1)).reduceByKey(lambda a,b:a + b)
media_peli2002 = anno_2002.join(num_votos_peli2002).map(lambda x:(x[0],(x[1][0]/x[1][1]))).sortByKey()
media_2002 = media_peli2002.map(lambda x: x[1]).mean()
media_2002
# Out:
# 3.5677800178850787

# %% [markdown]
# #### Año 2003

# %%
anno_2003 = ratings_splitted.filter(lambda x: x[3] == 2003).map(lambda x: (x[0],x[2])).reduceByKey(lambda a,b:a + b)
num_votos_peli2003 = ratings_splitted.filter(lambda x: x[3] == 2003).map(lambda x: (x[0],1)).reduceByKey(lambda a,b:a + b)
media_peli2003 = anno_2003.join(num_votos_peli2003).map(lambda x:(x[0],(x[1][0]/x[1][1]))).sortByKey()
media_2003 = media_peli2003.map(lambda x: x[1]).mean()
media_2003
# Out:
# 3.53197483211742

# %% [markdown]
# __SOLUCION:__ La mejor media se obtuvo en el año 2000 y no se encuentran grandes diferencias entre los años.

# %% [markdown]
# ## Tercera pregunta: ¿Cuál es la película más votada por los mayores de 60?

# %% [markdown]
# ¿Cuántos usuarios distintos tengo?

# %%
users_splitted.map(lambda x: x[0]).distinct().count()
# Out:
# 6040

# %% [markdown]
# Obtengo el id de los usuarios mayores de 60 años.

# %%
mayores_de_60 = users_splitted.filter(lambda x: int(x[2]) > 60).map(lambda x: x[0])

# %%
mayores_de_60.count()
# Out:
# 0

# %% [markdown]
# ¿Hay usuarios menores de 60?

# %%
menores_de_60 = users_splitted.filter(lambda x: int(x[2]) < 60).map(lambda x: x[0])

# %%
menores_de_60.count()
# Out:
# 6040

# %% [markdown]
# __SOLUCION:__ No hay mayores de 60 así que no hay peli más votada.

# %% [markdown]
# ## Cuarta pregunta: ¿Cuál es la puntuación media de las peliculas de acción del año 2000?

# %% [markdown]
# Obtengo las peliculas de accion del año 2000 de movies_splitted.

# %%
action_movies = movies_splitted.filter(lambda x: 'Action' in x[2]).filter(lambda x: '(2000)' in x[1]).map(lambda x: (int(x[0]),x[1]))

# %%
action_movies.take(4)
# Out:
# [(3300, 'Pitch Black (2000)'),
#  (3316, 'Reindeer Games (2000)'),
#  (3452, 'Romeo Must Die (2000)'),
#  (3555, 'U-571 (2000)')]

# %% [markdown]
# Del ejercicio 2 ya tengo una lista con los id de las pelis y las medias del año 2000.

# %%
media_peli.take(4)
# Out:
# [(1, 4.175),
#  (2, 3.7131782945736433),
#  (3, 3.9019607843137254),
#  (4, 4.190476190476191)]

# %% [markdown]
# Realizo un join.

# %%
media_action = action_movies.join(media_peli)

# %%
media_action.collect()
# Out:
# [(3300, ('Pitch Black (2000)', 3.9640883977900554)),
#  (3316, ('Reindeer Games (2000)', 4.0)),
#  (3452, ('Romeo Must Die (2000)', 4.426229508196721)),
#  (3578, ('Gladiator (2000)', 3.3948339483394836)),
#  (3624, ('Shanghai Noon (2000)', 4.027863777089784)),
#  (3744, ('Shaft (2000)', 4.083333333333333)),
#  (3898, ('Bait (2000)', 3.742574257425743)),
#  (3946, ('Get Carter (2000)', 3.734848484848485)),
#  (3555, ('U-571 (2000)', 3.108527131782946)),
#  (3563, ('Crow: Salvation, The (2000)', 3.843601895734597)),
#  (3593, ('Battlefield Earth (2000)', 3.390625)),
#  (3623, ('Mission: Impossible 2 (2000)', 3.6818181818181817)),
#  (3717, ('Gone in 60 Seconds (2000)', 3.78125)),
#  (3753, ('Patriot, The (2000)', 3.7755102040816326)),
#  (3755, ('Perfect Storm, The (2000)', 4.472222222222222)),
#  (3793, ('X-Men (2000)', 2.789473684210526)),
#  (3827, ('Space Cowboys (2000)', 3.747311827956989)),
#  (3879, ('Art of War, The (2000)', 3.3043478260869565)),
#  (3889, ('Highlander: Endgame (2000)', 4.293233082706767))]

# %% [markdown]
# Ya tenemos la media de cada peli de acción del 2000, también obtengo la media global de las pelis de acción del 2000.

# %%
medias_action_global = media_action.map(lambda x: x[1][1])

# %%
medias_action_global.mean()
# Out:
# 3.766404882296022

# %% [markdown]
# __SOLUCION:__ La media global de las pelis de acción del 2000 es de 3.76.

# %% [markdown]
# ## Quinta pregunta: ¿ Cuál es el año en que mayor número de usuarios votaron?

# %% [markdown]
# Calculo el número de usuarios distintos cada año.

# %% [markdown]
# #### Año 2000

# %%
anno2000users = ratings_splitted.filter(lambda x: x[3] == 2000).map(lambda x: x[1]).distinct().count()
anno2000users
# Out:
# 3678

# %% [markdown]
# #### Año 2001

# %%
anno2001users = ratings_splitted.filter(lambda x: x[3] == 2001).map(lambda x: x[1]).distinct().count()
anno2001users
# Out:
# 3289

# %% [markdown]
# #### Año 2002

# %%
anno2002users = ratings_splitted.filter(lambda x: x[3] == 2002).map(lambda x: x[1]).distinct().count()
anno2002users
# Out:
# 2971

# %% [markdown]
# #### Año 2003

# %%
anno2003users = ratings_splitted.filter(lambda x: x[3] == 2003).map(lambda x: x[1]).distinct().count()
anno2003users
# Out:
# 1601

# %% [markdown]
# __SOLUCION:__ El año que más usuarios votaron fue en el 2000.

# %% [markdown]
# ## Sexta pregunta: ¿ Cuál es la película con mejor puntación media?

# %% [markdown]
# Realiza una suma de las puntuaciones de todas las pelis.

# %%
pelis = ratings_splitted.map(lambda x: (x[0],x[2])).reduceByKey(lambda a,b: a + b)

# %%
pelis.take(5)
# Out:
# [(1, 222), (2, 479), (3, 199), (4, 88), (5, 623)]

# %% [markdown]
# Miro el número de veces ue fueron votadas.

# %%
votos_pelis = ratings_splitted.map(lambda x: (x[0],1)).reduceByKey(lambda a,b: a + b)

# %%
votos_pelis.take(5)
# Out:
# [(1, 53), (2, 129), (3, 51), (4, 21), (5, 198)]

# %% [markdown]
# Calculo la media.

# %%
medias = pelis.join(votos_pelis).map(lambda x:(x[0],(x[1][0]/x[1][1])))

# %%
medias.take(5)
# Out:
# [(1, 4.188679245283019),
#  (2, 3.7131782945736433),
#  (3, 3.9019607843137254),
#  (4, 4.190476190476191),
#  (5, 3.1464646464646466)]

# %% [markdown]
# Saco el id de la película con mayor media.

# %%
medias.max(lambda x: x[1])
# Out:
# (283, 4.962962962962963)

# %% [markdown]
# Selecciono la película con ese id en movies.splitted.

# %%
movies_splitted.filter(lambda x: int(x[0]) == 283).collect()
# Out:
# [['283', 'New Jersey Drive (1995)', 'Crime|Drama']]

# %% [markdown]
# __SOLUCIÓN:__ New Jersey Drive es la película con mejor media.
